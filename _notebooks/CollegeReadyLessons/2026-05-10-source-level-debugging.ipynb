# %% [markdown]
# <details class="college-ready-dropdown">
# <summary>Debugging and Testing</summary>
#
# <details class="college-ready-subdropdown">
# <summary>Source-Level Debugging</summary>
#
# Source-level debugging pauses code at specific lines so variable values and execution order can be inspected directly.
#
# <pre><code class="language-javascript">let total = 0;
# total += 5;
# total += 10;</code></pre>
#
# </details>
# </details>
