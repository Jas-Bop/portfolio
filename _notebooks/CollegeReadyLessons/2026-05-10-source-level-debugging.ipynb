# %% [raw]
# ---
# layout: post
# categories: [CSSE JavaScript]
# microblog: true
# codemirror: true
# title: Source Debugging Lesson
# description: Learn how to pause code and inspect it in DevTools and identify the Sources tab demo.
# permalink: /college-ready/source-level-debugging
# ---

# %% [markdown]
# ## Source Debugging Lesson
#
# Source Debugging Lesson focuses on this skill: **Pause code and inspect it in DevTools**
#
# When you review your project, you should be able to point to **the Sources tab demo** as evidence.

# %% [markdown]
# ## Why Source Debugging Lesson matters
#
# - This helps show that you can pause code and inspect it in DevTools.
# - A reviewer can verify it by checking the Sources tab demo.
# - The example below gives you a small starting point before you connect the idea to your own game.

# %%
# %%js
#
# // CODE_RUNNER: Source Debugging Notes - practice the idea below.
#
# // Goal: Pause code and inspect it in DevTools
# // Look for: the Sources tab demo
#
# const lesson = {
#   topic: "Source Debugging Notes",
#   evidence: "the Sources tab demo",
#   complete: false
# };
#
# function explainLesson(item) {
#   console.log(item.topic + ": " + item.evidence);
# }
#
# explainLesson(lesson);

# %% [markdown]
# ## Homework

# %%
# %%js
#
# // CODE_RUNNER: Homework - make your own example for Source Debugging Notes.
#
# // TODO: Write code that shows this skill:
# // Pause code and inspect it in DevTools
#
# console.log("Add your own example here.");
