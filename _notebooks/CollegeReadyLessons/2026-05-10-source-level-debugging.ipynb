# %% [raw]
# ---
# layout: post
# categories: [CSSE JavaScript]
# microblog: true
# codemirror: true
# title: Source Debugging Lesson
# description: Learn what Source-level debugging means, how it works in the Astro Platformer game, and how to practice it with a small homework task.
# permalink: /college-ready/source-level-debugging
# ---

# %% [markdown]
# ## Source Debugging Lesson
#
# ### What it is
#
# Source-level debugging means pausing code in DevTools Sources so you can inspect variables step by step.
#
# ### How it connects to our Astro Platformer
#
# Astro Platformer can be debugged by pausing inside the physics loop to inspect velocity, position, collision flags, or coin state.
#
# Evidence to check: `_projects/games/astronaut-platformer-game/levels/astroplatformer.js`, the playable page `/astro-platgame/`, and the gravity write-up `/gravity_blog`.

# %% [markdown]
# ## Why this matters in Astro Platformer
#
# - A breakpoint near gravity or collision code can show why the astronaut lands or falls.
# - This lesson is not separate from the project; it is a way to explain one part of our Astro Platformer game.
# - A reviewer should be able to connect this topic back to the actual game code, gameplay, or documentation.

# %%
# %%js
#
# // CODE_RUNNER: Source Debugging Lesson - Astro Platformer connection.
#
# const astroLesson = {
#   game: "Astro Platformer",
#   topic: "Source-level debugging",
#   codeEvidence: "_projects/games/astronaut-platformer-game/levels/astroplatformer.js",
#   playablePage: "/astro-platgame/",
#   connection: "Astro Platformer can be debugged by pausing inside the physics loop to inspect velocity, position, collision flags, or coin state."
# };
#
# function explainAstroConnection(lesson) {
#   console.log(lesson.topic + " in " + lesson.game);
#   console.log("Evidence: " + lesson.codeEvidence);
#   console.log(lesson.connection);
# }
#
# explainAstroConnection(astroLesson);

# %% [markdown]
# ## Homework
#
# Pick one place in astroplatformer.js where a breakpoint would help find a bug.
#
# Keep it small: write 2-3 sentences or fill in the starter code below. Your answer should mention **Astro Platformer** and one specific file, feature, variable, or gameplay moment.

# %%
# %%js
#
# // CODE_RUNNER: Homework - connect Source-level debugging back to Astro Platformer.
#
# const homework = {
#   game: "Astro Platformer",
#   topic: "Source-level debugging",
#   fileToCheck: "_projects/games/astronaut-platformer-game/levels/astroplatformer.js",
#   task: "Pick one place in astroplatformer.js where a breakpoint would help find a bug.",
#   yourAnswer: "Fill in the feature and variable you would inspect at a breakpoint."
# };
#
# console.log("Homework topic: " + homework.topic);
# console.log("Task: " + homework.task);
# console.log("My answer: " + homework.yourAnswer);
