# %% [raw]
# ---
# layout: post
# categories: [CSSE JavaScript]
# microblog: true
# codemirror: true
# title: API Lesson
# description: Learn what API integration means, how it works in the Astro Platformer game, and how to practice it with a small homework task.
# permalink: /college-ready/api-integration
# ---

# %% [markdown]
# ## API Lesson
#
# ### What it is
#
# API stands for Application Programming Interface. An API is a way for one program to request data or send data to another program.
#
# ### How it connects to our Astro Platformer
#
# Astro Platformer connects to backend API settings through pythonURI, javaURI, and fetchOptions so game features like leaderboard data can be saved or loaded.
#
# Evidence to check: `_projects/games/astronaut-platformer-game/levels/astroplatformer.js`, the playable page `/astro-platgame/`, and the gravity write-up `/gravity_blog`.

# %% [markdown]
# ## Why this matters in Astro Platformer
#
# - The game page imports API config values and passes them into the game environment and leaderboard.
# - This lesson is not separate from the project; it is a way to explain one part of our Astro Platformer game.
# - A reviewer should be able to connect this topic back to the actual game code, gameplay, or documentation.

# %%
# %%js
#
# // CODE_RUNNER: API Lesson - Astro Platformer connection.
#
# const astroLesson = {
#   game: "Astro Platformer",
#   topic: "API integration",
#   codeEvidence: "_projects/games/astronaut-platformer-game/levels/astroplatformer.js",
#   playablePage: "/astro-platgame/",
#   connection: "Astro Platformer connects to backend API settings through pythonURI, javaURI, and fetchOptions so game features like leaderboard data can be saved or loaded."
# };
#
# function explainAstroConnection(lesson) {
#   console.log(lesson.topic + " in " + lesson.game);
#   console.log("Evidence: " + lesson.codeEvidence);
#   console.log(lesson.connection);
# }
#
# explainAstroConnection(astroLesson);

# %% [markdown]
# ## Homework
#
# Explain one piece of data Astro Platformer might send to an API, such as coins collected or a score.
#
# Keep it small: write 2-3 sentences or fill in the starter code below. Your answer should mention **Astro Platformer** and one specific file, feature, variable, or gameplay moment.

# %%
# %%js
#
# // CODE_RUNNER: Homework - connect API integration back to Astro Platformer.
#
# const homework = {
#   game: "Astro Platformer",
#   topic: "API integration",
#   fileToCheck: "_projects/games/astronaut-platformer-game/levels/astroplatformer.js",
#   task: "Explain one piece of data Astro Platformer might send to an API, such as coins collected or a score.",
#   yourAnswer: "Fill in the dataName and whyServerNeedsIt fields for one Astro Platformer API example."
# };
#
# console.log("Homework topic: " + homework.topic);
# console.log("Task: " + homework.task);
# console.log("My answer: " + homework.yourAnswer);
