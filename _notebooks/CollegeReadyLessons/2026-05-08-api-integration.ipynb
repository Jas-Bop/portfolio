# %% [raw]
# ---
# layout: post
# categories: [CSSE JavaScript]
# microblog: true
# codemirror: true
# title: API Lesson
# description: Learn how to send and get data from an API and identify fetch code.
# permalink: /college-ready/api-integration
# ---

# %% [markdown]
# ## API Lesson
#
# API Lesson focuses on this skill: **Send and get data from an API**
#
# When you review your project, you should be able to point to **fetch code** as evidence.

# %% [markdown]
# ## Why API Lesson matters
#
# - This helps show that you can send and get data from an API.
# - A reviewer can verify it by checking fetch code.
# - The example below gives you a small starting point before you connect the idea to your own game.

# %%
# %%js
#
# // CODE_RUNNER: API Lesson - practice the idea below.
#
# // Goal: Send and get data from an API
# // Look for: fetch code
#
# const lesson = {
#   topic: "API",
#   evidence: "fetch code",
#   complete: false
# };
#
# function explainLesson(item) {
#   console.log(item.topic + ": " + item.evidence);
# }
#
# explainLesson(lesson);

# %% [markdown]
# ## Homework

# %%
# %%js
#
# // CODE_RUNNER: Homework - make your own example for API Lesson.
#
# // TODO: Write code that shows this skill:
# // Send and get data from an API
#
# console.log("Add your own example here.");
