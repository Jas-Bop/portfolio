# %% [markdown]
# <details class="college-ready-dropdown">
# <summary>APIs and Data Loading</summary>
#
# <details class="college-ready-subdropdown">
# <summary>API Integration</summary>
#
# API integration prepares a program to communicate with another program. JavaScript often organizes request information as objects before sending data.
#
# <pre><code class="language-javascript">const request = { method: "POST", endpoint: "/api/scores" };</code></pre>
#
# </details>
# </details>
