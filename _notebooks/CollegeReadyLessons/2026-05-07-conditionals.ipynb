# %% [markdown]
# <details class="college-ready-dropdown">
# <summary>Programming Fundamentals</summary>
#
# <details class="college-ready-subdropdown">
# <summary>If/Else Statements</summary>
#
# If/else statements let a program choose between different actions. JavaScript checks a condition and runs the branch that matches the result.
#
# <pre><code class="language-javascript">let grade = 82;
#
# if (grade &gt;= 80) {
#   console.log("B range");
# } else {
#   console.log("Keep improving");
# }</code></pre>
#
# </details>
# </details>
