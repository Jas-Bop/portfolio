# %% [raw]
# ---
# layout: post
# categories: [CSSE JavaScript]
# microblog: true
# codemirror: true
# title: If/Else Lesson
# description: Learn how to use if/else choices in the game and identify if and else code.
# permalink: /college-ready/conditionals
# ---

# %% [markdown]
# ## If/Else Lesson
#
# If/Else Lesson focuses on this skill: **Use if/else choices in the game**
#
# When you review your project, you should be able to point to **if and else code** as evidence.

# %% [markdown]
# ## Why If/Else Lesson matters
#
# - This helps show that you can use if/else choices in the game.
# - A reviewer can verify it by checking if and else code.
# - The example below gives you a small starting point before you connect the idea to your own game.

# %%
# %%js
#
# // CODE_RUNNER: If/Else Lesson - practice the idea below.
#
# // Goal: Use if/else choices in the game
# // Look for: if and else code
#
# const lesson = {
#   topic: "If/Else",
#   evidence: "if and else code",
#   complete: false
# };
#
# function explainLesson(item) {
#   console.log(item.topic + ": " + item.evidence);
# }
#
# explainLesson(lesson);

# %% [markdown]
# ## Homework

# %%
# %%js
#
# // CODE_RUNNER: Homework - make your own example for If/Else Lesson.
#
# // TODO: Write code that shows this skill:
# // Use if/else choices in the game
#
# console.log("Add your own example here.");
