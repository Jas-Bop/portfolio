# %% [raw]
# ---
# layout: post
# categories: [CSSE JavaScript]
# microblog: true
# codemirror: true
# title: If/Else Lesson
# description: Learn what If/else statements means, how it works in the Astro Platformer game, and how to practice it with a small homework task.
# permalink: /college-ready/conditionals
# ---

# %% [markdown]
# ## If/Else Lesson
#
# ### What it is
#
# An if/else statement lets a program choose between different actions. The if part runs when a condition is true, and the else part runs when it is false.
#
# ### How it connects to our Astro Platformer
#
# Astro Platformer uses if/else choices to decide whether the astronaut jumps, collects a coin, hits a spike, reaches the flag, or keeps playing.
#
# Evidence to check: `_projects/games/astronaut-platformer-game/levels/astroplatformer.js`, the playable page `/astro-platgame/`, and the gravity write-up `/gravity_blog`.

# %% [markdown]
# ## Why this matters in Astro Platformer
#
# - A condition can check if the player is touching a coin; if yes, collect it, otherwise keep drawing it.
# - This lesson is not separate from the project; it is a way to explain one part of our Astro Platformer game.
# - A reviewer should be able to connect this topic back to the actual game code, gameplay, or documentation.

# %%
# %%js
#
# // CODE_RUNNER: If/Else Lesson - Astro Platformer connection.
#
# const astroLesson = {
#   game: "Astro Platformer",
#   topic: "If/else statements",
#   codeEvidence: "_projects/games/astronaut-platformer-game/levels/astroplatformer.js",
#   playablePage: "/astro-platgame/",
#   connection: "Astro Platformer uses if/else choices to decide whether the astronaut jumps, collects a coin, hits a spike, reaches the flag, or keeps playing."
# };
#
# function explainAstroConnection(lesson) {
#   console.log(lesson.topic + " in " + lesson.game);
#   console.log("Evidence: " + lesson.codeEvidence);
#   console.log(lesson.connection);
# }
#
# explainAstroConnection(astroLesson);

# %% [markdown]
# ## Homework
#
# Write one if/else rule for the Astro Platformer player, such as what should happen when lives are greater than 0 or equal to 0.
#
# Keep it small: write 2-3 sentences or fill in the starter code below. Your answer should mention **Astro Platformer** and one specific file, feature, variable, or gameplay moment.

# %%
# %%js
#
# // CODE_RUNNER: Homework - connect If/else statements back to Astro Platformer.
#
# const homework = {
#   game: "Astro Platformer",
#   topic: "If/else statements",
#   fileToCheck: "_projects/games/astronaut-platformer-game/levels/astroplatformer.js",
#   task: "Write one if/else rule for the Astro Platformer player, such as what should happen when lives are greater than 0 or equal to 0.",
#   yourAnswer: "Fill in the two messages so the if/else rule matches an Astro Platformer situation."
# };
#
# console.log("Homework topic: " + homework.topic);
# console.log("Task: " + homework.task);
# console.log("My answer: " + homework.yourAnswer);
