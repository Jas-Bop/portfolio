# %% [raw]
# ---
# layout: post
# categories: [CSSE JavaScript]
# microblog: true
# codemirror: true
# title: Loops Lesson
# description: Learn what Loops means, how it works in the Astro Platformer game, and how to practice it with a small homework task.
# permalink: /college-ready/iteration
# ---

# %% [markdown]
# ## Loops Lesson
#
# ### What it is
#
# A loop repeats code. Loops are useful when the same action must happen for many items, like checking every platform or drawing every coin.
#
# ### How it connects to our Astro Platformer
#
# Astro Platformer uses repeated checks for platforms, spikes, and coins so the player can interact with the whole level instead of one object at a time.
#
# Evidence to check: `_projects/games/astronaut-platformer-game/levels/astroplatformer.js`, the playable page `/astro-platgame/`, and the gravity write-up `/gravity_blog`.

# %% [markdown]
# ## Why this matters in Astro Platformer
#
# - The game can loop through all coins to see whether the astronaut collected any of them.
# - This lesson is not separate from the project; it is a way to explain one part of our Astro Platformer game.
# - A reviewer should be able to connect this topic back to the actual game code, gameplay, or documentation.

# %%
# %%js
#
# // CODE_RUNNER: Loops Lesson - Astro Platformer connection.
#
# const astroLesson = {
#   game: "Astro Platformer",
#   topic: "Loops",
#   codeEvidence: "_projects/games/astronaut-platformer-game/levels/astroplatformer.js",
#   playablePage: "/astro-platgame/",
#   connection: "Astro Platformer uses repeated checks for platforms, spikes, and coins so the player can interact with the whole level instead of one object at a time."
# };
#
# function explainAstroConnection(lesson) {
#   console.log(lesson.topic + " in " + lesson.game);
#   console.log("Evidence: " + lesson.codeEvidence);
#   console.log(lesson.connection);
# }
#
# explainAstroConnection(astroLesson);

# %% [markdown]
# ## Homework
#
# Choose one group in Astro Platformer that needs a loop: platforms, spikes, or coins. Explain why one-by-one code would be annoying.
#
# Keep it small: write 2-3 sentences or fill in the starter code below. Your answer should mention **Astro Platformer** and one specific file, feature, variable, or gameplay moment.

# %%
# %%js
#
# // CODE_RUNNER: Homework - connect Loops back to Astro Platformer.
#
# const homework = {
#   game: "Astro Platformer",
#   topic: "Loops",
#   fileToCheck: "_projects/games/astronaut-platformer-game/levels/astroplatformer.js",
#   task: "Choose one group in Astro Platformer that needs a loop: platforms, spikes, or coins. Explain why one-by-one code would be annoying.",
#   yourAnswer: "Set objectGroup to platforms, spikes, or coins, then write what the loop checks."
# };
#
# console.log("Homework topic: " + homework.topic);
# console.log("Task: " + homework.task);
# console.log("My answer: " + homework.yourAnswer);
