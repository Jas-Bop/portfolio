# %% [raw]
# ---
# layout: post
# categories: [CSSE JavaScript]
# microblog: true
# codemirror: true
# title: Loops Lesson
# description: Learn how to use loops to repeat game actions and identify for, forEach, or while loops.
# permalink: /college-ready/iteration
# ---

# %% [markdown]
# ## Loops Lesson
#
# Loops Lesson focuses on this skill: **Use loops to repeat game actions**
#
# When you review your project, you should be able to point to **for, forEach, or while loops** as evidence.

# %% [markdown]
# ## Why Loops Lesson matters
#
# - This helps show that you can use loops to repeat game actions.
# - A reviewer can verify it by checking for, forEach, or while loops.
# - The example below gives you a small starting point before you connect the idea to your own game.

# %%
# %%js
#
# // CODE_RUNNER: Loops Lesson - practice the idea below.
#
# // Goal: Use loops to repeat game actions
# // Look for: for, forEach, or while loops
#
# const lesson = {
#   topic: "Loops",
#   evidence: "for, forEach, or while loops",
#   complete: false
# };
#
# function explainLesson(item) {
#   console.log(item.topic + ": " + item.evidence);
# }
#
# explainLesson(lesson);

# %% [markdown]
# ## Homework

# %%
# %%js
#
# // CODE_RUNNER: Homework - make your own example for Loops Lesson.
#
# // TODO: Write code that shows this skill:
# // Use loops to repeat game actions
#
# console.log("Add your own example here.");
