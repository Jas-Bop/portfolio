# %% [raw]
# ---
# layout: post
# categories: [CSSE JavaScript]
# microblog: true
# codemirror: true
# title: Methods Lesson
# description: Learn how to write methods that take 2 or more inputs and identify method names and their inputs.
# permalink: /college-ready/methods-parameters
# ---

# %% [markdown]
# ## Methods Lesson
#
# Methods Lesson focuses on this skill: **Write methods that take 2 or more inputs**
#
# When you review your project, you should be able to point to **method names and their inputs** as evidence.

# %% [markdown]
# ## Why Methods Lesson matters
#
# - This helps show that you can write methods that take 2 or more inputs.
# - A reviewer can verify it by checking method names and their inputs.
# - The example below gives you a small starting point before you connect the idea to your own game.

# %%
# %%js
#
# // CODE_RUNNER: Methods Lesson - practice the idea below.
#
# // Goal: Write methods that take 2 or more inputs
# // Look for: method names and their inputs
#
# const lesson = {
#   topic: "Methods",
#   evidence: "method names and their inputs",
#   complete: false
# };
#
# function explainLesson(item) {
#   console.log(item.topic + ": " + item.evidence);
# }
#
# explainLesson(lesson);

# %% [markdown]
# ## Homework

# %%
# %%js
#
# // CODE_RUNNER: Homework - make your own example for Methods Lesson.
#
# // TODO: Write code that shows this skill:
# // Write methods that take 2 or more inputs
#
# console.log("Add your own example here.");
