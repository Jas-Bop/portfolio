# %% [raw]
# ---
# layout: post
# categories: [CSSE JavaScript]
# microblog: true
# codemirror: true
# title: Methods Lesson
# description: Learn what Methods and parameters means, how it works in the Astro Platformer game, and how to practice it with a small homework task.
# permalink: /college-ready/methods-parameters
# ---

# %% [markdown]
# ## Methods Lesson
#
# ### What it is
#
# A method is a function that belongs to an object or class. A parameter is an input value passed into a method.
#
# ### How it connects to our Astro Platformer
#
# Astro Platformer uses methods to update objects, collect coins, rebuild layouts, scale positions, and handle input.
#
# Evidence to check: `_projects/games/astronaut-platformer-game/levels/astroplatformer.js`, the playable page `/astro-platgame/`, and the gravity write-up `/gravity_blog`.

# %% [markdown]
# ## Why this matters in Astro Platformer
#
# - A scaling helper can take source, sx, and sy parameters and return a resized platform.
# - This lesson is not separate from the project; it is a way to explain one part of our Astro Platformer game.
# - A reviewer should be able to connect this topic back to the actual game code, gameplay, or documentation.

# %%
# %%js
#
# // CODE_RUNNER: Methods Lesson - Astro Platformer connection.
#
# const astroLesson = {
#   game: "Astro Platformer",
#   topic: "Methods and parameters",
#   codeEvidence: "_projects/games/astronaut-platformer-game/levels/astroplatformer.js",
#   playablePage: "/astro-platgame/",
#   connection: "Astro Platformer uses methods to update objects, collect coins, rebuild layouts, scale positions, and handle input."
# };
#
# function explainAstroConnection(lesson) {
#   console.log(lesson.topic + " in " + lesson.game);
#   console.log("Evidence: " + lesson.codeEvidence);
#   console.log(lesson.connection);
# }
#
# explainAstroConnection(astroLesson);

# %% [markdown]
# ## Homework
#
# Design one small method that would help Astro Platformer, with at least two parameters.
#
# Keep it small: write 2-3 sentences or fill in the starter code below. Your answer should mention **Astro Platformer** and one specific file, feature, variable, or gameplay moment.

# %%
# %%js
#
# // CODE_RUNNER: Homework - connect Methods and parameters back to Astro Platformer.
#
# const homework = {
#   game: "Astro Platformer",
#   topic: "Methods and parameters",
#   fileToCheck: "_projects/games/astronaut-platformer-game/levels/astroplatformer.js",
#   task: "Design one small method that would help Astro Platformer, with at least two parameters.",
#   yourAnswer: "Fill in a method name and two parameters for a platformer helper."
# };
#
# console.log("Homework topic: " + homework.topic);
# console.log("Task: " + homework.task);
# console.log("My answer: " + homework.yourAnswer);
