# %% [raw]
# ---
# layout: post
# categories: [CSSE JavaScript]
# microblog: true
# codemirror: true
# title: UI Lesson
# description: Learn how to inspect page elements and styles and identify the Elements tab demo.
# permalink: /college-ready/element-inspection
# ---

# %% [markdown]
# ## UI Lesson
#
# UI Lesson focuses on this skill: **Inspect page elements and styles**
#
# When you review your project, you should be able to point to **the Elements tab demo** as evidence.

# %% [markdown]
# ## Why UI Lesson matters
#
# - This helps show that you can inspect page elements and styles.
# - A reviewer can verify it by checking the Elements tab demo.
# - The example below gives you a small starting point before you connect the idea to your own game.

# %%
# %%js
#
# // CODE_RUNNER: UI Lesson - practice the idea below.
#
# // Goal: Inspect page elements and styles
# // Look for: the Elements tab demo
#
# const lesson = {
#   topic: "UI",
#   evidence: "the Elements tab demo",
#   complete: false
# };
#
# function explainLesson(item) {
#   console.log(item.topic + ": " + item.evidence);
# }
#
# explainLesson(lesson);

# %% [markdown]
# ## Homework

# %%
# %%js
#
# // CODE_RUNNER: Homework - make your own example for UI Lesson.
#
# // TODO: Write code that shows this skill:
# // Inspect page elements and styles
#
# console.log("Add your own example here.");
