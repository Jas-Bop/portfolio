# %% [raw]
# ---
# layout: post
# categories: [CSSE JavaScript]
# microblog: true
# codemirror: true
# title: UI Lesson
# description: Learn what Element inspection means, how it works in the Astro Platformer game.
# permalink: /college-ready/element-inspection
# ---

# %% [markdown]
# ## UI Lesson
#
# ### What it is
#
# Element inspection means using browser DevTools to look at the HTML and CSS that create what you see on the page.
#
# ### How it connects to our games
#
# Astro Platformer uses page elements for the game container, prompt dropdown, canvas, HUD, death screen, and leaderboard.
#
# Evidence to check: `_projects/games/astronaut-platformer-game/levels/astroplatformer.js`, the playable page `/astro-platgame/`, and the gravity write-up `/gravity_blog`.

# %% [markdown]
# ## Why it matters for all lessons
#
# - Inspecting the gameContainer can help confirm the canvas is being created in the right place.
# - This lesson is not separate from the project; it is a way to explain one part of our Astro Platformer game.
# - A reviewer should be able to connect this topic back to the actual game code, gameplay, or documentation.

# %%
# %%js
#
# // CODE_RUNNER: UI Lesson - Astro Platformer connection.
#
# const astroLesson = {
#   game: "Astro Platformer",
#   topic: "Element inspection",
#   codeEvidence: "_projects/games/astronaut-platformer-game/levels/astroplatformer.js",
#   playablePage: "/astro-platgame/",
#   connection: "Astro Platformer uses page elements for the game container, prompt dropdown, canvas, HUD, death screen, and leaderboard."
# };
#
# function explainAstroConnection(lesson) {
#   console.log(lesson.topic + " in " + lesson.game);
#   console.log("Evidence: " + lesson.codeEvidence);
#   console.log(lesson.connection);
# }
#
# explainAstroConnection(astroLesson);
