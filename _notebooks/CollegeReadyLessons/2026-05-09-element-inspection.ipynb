# %% [markdown]
# <details class="college-ready-dropdown">
# <summary>Debugging and Testing</summary>
#
# <details class="college-ready-subdropdown">
# <summary>Element Inspection</summary>
#
# Element inspection studies the HTML and CSS structure behind a web page and connects visible content to tags, attributes, classes, and styles.
#
# <pre><code class="language-javascript">const inspectedElement = { tag: "button", id: "save-button", text: "Save" };</code></pre>
#
# </details>
# </details>
