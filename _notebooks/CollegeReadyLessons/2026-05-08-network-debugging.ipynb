# %% [raw]
# ---
# layout: post
# categories: [CSSE JavaScript]
# microblog: true
# codemirror: true
# title: Network Lesson
# description: Learn how to check API requests in the Network tab and identify the Network tab demo.
# permalink: /college-ready/network-debugging
# ---

# %% [markdown]
# ## Network Lesson
#
# Network Lesson focuses on this skill: **Check API requests in the Network tab**
#
# When you review your project, you should be able to point to **the Network tab demo** as evidence.

# %% [markdown]
# ## Why Network Lesson matters
#
# - This helps show that you can check API requests in the Network tab.
# - A reviewer can verify it by checking the Network tab demo.
# - The example below gives you a small starting point before you connect the idea to your own game.

# %%
# %%js
#
# // CODE_RUNNER: Network Lesson - practice the idea below.
#
# // Goal: Check API requests in the Network tab
# // Look for: the Network tab demo
#
# const lesson = {
#   topic: "Network",
#   evidence: "the Network tab demo",
#   complete: false
# };
#
# function explainLesson(item) {
#   console.log(item.topic + ": " + item.evidence);
# }
#
# explainLesson(lesson);

# %% [markdown]
# ## Homework

# %%
# %%js
#
# // CODE_RUNNER: Homework - make your own example for Network Lesson.
#
# // TODO: Write code that shows this skill:
# // Check API requests in the Network tab
#
# console.log("Add your own example here.");
