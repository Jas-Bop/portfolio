# %% [markdown]
# <details class="college-ready-dropdown">
# <summary>Debugging and Testing</summary>
#
# <details class="college-ready-subdropdown">
# <summary>Network Debugging</summary>
#
# Network debugging inspects requests and responses made by a web page. It helps find missing files and failed API calls.
#
# <pre><code class="language-javascript">const response = { url: "/api/profile", status: 404 };</code></pre>
#
# </details>
# </details>
