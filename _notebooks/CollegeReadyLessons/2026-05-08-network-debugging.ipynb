# %% [raw]
# ---
# layout: post
# categories: [CSSE JavaScript]
# microblog: true
# codemirror: true
# title: Network Lesson
# description: Learn what Network debugging means, how it works in the Astro Platformer game, and how to practice it with a small homework task.
# permalink: /college-ready/network-debugging
# ---

# %% [markdown]
# ## Network Lesson
#
# ### What it is
#
# Network debugging means using the browser Network tab to inspect requests, responses, status codes, and loaded files.
#
# ### How it connects to our Astro Platformer
#
# Astro Platformer can use the Network tab to check whether game scripts, images, music, and API/leaderboard requests load correctly.
#
# Evidence to check: `_projects/games/astronaut-platformer-game/levels/astroplatformer.js`, the playable page `/astro-platgame/`, and the gravity write-up `/gravity_blog`.

# %% [markdown]
# ## Why this matters in Astro Platformer
#
# - If the astronaut sprite or leaderboard does not load, the Network tab can show whether a file path or API request failed.
# - This lesson is not separate from the project; it is a way to explain one part of our Astro Platformer game.
# - A reviewer should be able to connect this topic back to the actual game code, gameplay, or documentation.

# %%
# %%js
#
# // CODE_RUNNER: Network Lesson - Astro Platformer connection.
#
# const astroLesson = {
#   game: "Astro Platformer",
#   topic: "Network debugging",
#   codeEvidence: "_projects/games/astronaut-platformer-game/levels/astroplatformer.js",
#   playablePage: "/astro-platgame/",
#   connection: "Astro Platformer can use the Network tab to check whether game scripts, images, music, and API/leaderboard requests load correctly."
# };
#
# function explainAstroConnection(lesson) {
#   console.log(lesson.topic + " in " + lesson.game);
#   console.log("Evidence: " + lesson.codeEvidence);
#   console.log(lesson.connection);
# }
#
# explainAstroConnection(astroLesson);

# %% [markdown]
# ## Homework
#
# Name one Astro Platformer file or request you would check in the Network tab if the game page looked broken.
#
# Keep it small: write 2-3 sentences or fill in the starter code below. Your answer should mention **Astro Platformer** and one specific file, feature, variable, or gameplay moment.

# %%
# %%js
#
# // CODE_RUNNER: Homework - connect Network debugging back to Astro Platformer.
#
# const homework = {
#   game: "Astro Platformer",
#   topic: "Network debugging",
#   fileToCheck: "_projects/games/astronaut-platformer-game/levels/astroplatformer.js",
#   task: "Name one Astro Platformer file or request you would check in the Network tab if the game page looked broken.",
#   yourAnswer: "Pick one asset or API request and write what a successful Network result should show."
# };
#
# console.log("Homework topic: " + homework.topic);
# console.log("Task: " + homework.task);
# console.log("My answer: " + homework.yourAnswer);
