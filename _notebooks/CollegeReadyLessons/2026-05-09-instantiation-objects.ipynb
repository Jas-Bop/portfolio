# %% [raw]
# ---
# layout: post
# categories: [CSSE JavaScript]
# microblog: true
# codemirror: true
# title: Objects Lesson
# description: Learn how to create game objects in the level setup and identify the GameLevel setup.
# permalink: /college-ready/instantiation-objects
# ---

# %% [markdown]
# ## Objects Lesson
#
# Objects Lesson focuses on this skill: **Create game objects in the level setup**
#
# When you review your project, you should be able to point to **the GameLevel setup** as evidence.

# %% [markdown]
# ## Why Objects Lesson matters
#
# - This helps show that you can create game objects in the level setup.
# - A reviewer can verify it by checking the GameLevel setup.
# - The example below gives you a small starting point before you connect the idea to your own game.

# %%
# %%js
#
# // CODE_RUNNER: Objects Lesson - practice the idea below.
#
# // Goal: Create game objects in the level setup
# // Look for: the GameLevel setup
#
# const lesson = {
#   topic: "Objects",
#   evidence: "the GameLevel setup",
#   complete: false
# };
#
# function explainLesson(item) {
#   console.log(item.topic + ": " + item.evidence);
# }
#
# explainLesson(lesson);

# %% [markdown]
# ## Homework

# %%
# %%js
#
# // CODE_RUNNER: Homework - make your own example for Objects Lesson.
#
# // TODO: Write code that shows this skill:
# // Create game objects in the level setup
#
# console.log("Add your own example here.");
