# %% [raw]
# ---
# layout: post
# categories: [CSSE JavaScript]
# microblog: true
# codemirror: true
# title: Objects Lesson
# description: Learn what Object instantiation means, how it works in the Astro Platformer game, and how to practice it with a small homework task.
# permalink: /college-ready/instantiation-objects
# ---

# %% [markdown]
# ## Objects Lesson
#
# ### What it is
#
# Object instantiation means creating a real object from a class or template so the program can use it.
#
# ### How it connects to our Astro Platformer
#
# Astro Platformer instantiates level objects like backgrounds, players, coins, platforms, and leaderboard helpers.
#
# Evidence to check: `_projects/games/astronaut-platformer-game/levels/astroplatformer.js`, the playable page `/astro-platgame/`, and the gravity write-up `/gravity_blog`.

# %% [markdown]
# ## Why this matters in Astro Platformer
#
# - The game page creates the AstroPlatformer level as part of the gameLevelClasses list.
# - This lesson is not separate from the project; it is a way to explain one part of our Astro Platformer game.
# - A reviewer should be able to connect this topic back to the actual game code, gameplay, or documentation.

# %%
# %%js
#
# // CODE_RUNNER: Objects Lesson - Astro Platformer connection.
#
# const astroLesson = {
#   game: "Astro Platformer",
#   topic: "Object instantiation",
#   codeEvidence: "_projects/games/astronaut-platformer-game/levels/astroplatformer.js",
#   playablePage: "/astro-platgame/",
#   connection: "Astro Platformer instantiates level objects like backgrounds, players, coins, platforms, and leaderboard helpers."
# };
#
# function explainAstroConnection(lesson) {
#   console.log(lesson.topic + " in " + lesson.game);
#   console.log("Evidence: " + lesson.codeEvidence);
#   console.log(lesson.connection);
# }
#
# explainAstroConnection(astroLesson);

# %% [markdown]
# ## Homework
#
# Pick one object that Astro Platformer needs to create before the level can work.
#
# Keep it small: write 2-3 sentences or fill in the starter code below. Your answer should mention **Astro Platformer** and one specific file, feature, variable, or gameplay moment.

# %%
# %%js
#
# // CODE_RUNNER: Homework - connect Object instantiation back to Astro Platformer.
#
# const homework = {
#   game: "Astro Platformer",
#   topic: "Object instantiation",
#   fileToCheck: "_projects/games/astronaut-platformer-game/levels/astroplatformer.js",
#   task: "Pick one object that Astro Platformer needs to create before the level can work.",
#   yourAnswer: "Fill in one class/object name and the job it does in the level."
# };
#
# console.log("Homework topic: " + homework.topic);
# console.log("Task: " + homework.task);
# console.log("My answer: " + homework.yourAnswer);
