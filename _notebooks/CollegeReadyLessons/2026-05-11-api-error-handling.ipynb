# %% [markdown]
# <details class="college-ready-dropdown">
# <summary>APIs and Data Loading</summary>
#
# <details class="college-ready-subdropdown">
# <summary>API Error Handling</summary>
#
# API error handling prepares code for failed or unexpected responses. Strong programs handle both success and failure paths.
#
# <pre><code class="language-javascript">const response = { ok: false, status: 503 };
# if (!response.ok) console.log(response.status);</code></pre>
#
# </details>
# </details>
