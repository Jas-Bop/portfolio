# %% [raw]
# ---
# layout: post
# categories: [CSSE JavaScript]
# microblog: true
# codemirror: true
# title: API Errors Lesson
# description: Learn how to handle API errors safely and identify try/catch or failed fetch handling.
# permalink: /college-ready/api-error-handling
# ---

# %% [markdown]
# ## API Errors Lesson
#
# API Errors Lesson focuses on this skill: **Handle API errors safely**
#
# When you review your project, you should be able to point to **try/catch or failed fetch handling** as evidence.

# %% [markdown]
# ## Why API Errors Lesson matters
#
# - This helps show that you can handle API errors safely.
# - A reviewer can verify it by checking try/catch or failed fetch handling.
# - The example below gives you a small starting point before you connect the idea to your own game.

# %%
# %%js
#
# // CODE_RUNNER: API Errors Lesson - practice the idea below.
#
# // Goal: Handle API errors safely
# // Look for: try/catch or failed fetch handling
#
# const lesson = {
#   topic: "API Errors",
#   evidence: "try/catch or failed fetch handling",
#   complete: false
# };
#
# function explainLesson(item) {
#   console.log(item.topic + ": " + item.evidence);
# }
#
# explainLesson(lesson);

# %% [markdown]
# ## Homework

# %%
# %%js
#
# // CODE_RUNNER: Homework - make your own example for API Errors Lesson.
#
# // TODO: Write code that shows this skill:
# // Handle API errors safely
#
# console.log("Add your own example here.");
