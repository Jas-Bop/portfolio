# %% [markdown]
# <details class="college-ready-dropdown">
# <summary>Documentation</summary>
#
# <details class="college-ready-subdropdown">
# <summary>Code Comments</summary>
#
# Code comments are notes written for humans. They explain intent and context while JavaScript ignores them during execution.
#
# <pre><code class="language-javascript">// Add points after a correct answer.
# let score = 0;
# score += 10;</code></pre>
#
# </details>
# </details>
