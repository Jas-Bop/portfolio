# %% [raw]
# ---
# layout: post
# categories: [CSSE JavaScript]
# microblog: true
# codemirror: true
# title: Comments Lesson
# description: Learn what Code comments means, how it works in the Astro Platformer game.
# permalink: /college-ready/code-comments
# ---

# %% [markdown]
# ## Comments Lesson
#
# ### What it is
#
# A code comment is text for humans that explains code but does not run as part of the program.
#
# ### How it connects to our games
#
# Astro Platformer uses comments to explain the physics loop, platform collision, gravity, moving platforms, spike death, and the route through the level.
#
# Evidence to check: `_projects/games/astronaut-platformer-game/levels/astroplatformer.js`, the playable page `/astro-platgame/`, and the gravity write-up `/gravity_blog`.

# %% [markdown]
# ## Why it matters for all lessons
#
# - A short comment before a collision check can explain why the code snaps the astronaut onto a platform.
# - This lesson is not separate from the project; it is a way to explain one part of our Astro Platformer game.
# - A reviewer should be able to connect this topic back to the actual game code, gameplay, or documentation.

# %%
# %%js
#
# // CODE_RUNNER: Comments Lesson - Astro Platformer connection.
#
# const astroLesson = {
#   game: "Astro Platformer",
#   topic: "Code comments",
#   codeEvidence: "_projects/games/astronaut-platformer-game/levels/astroplatformer.js",
#   playablePage: "/astro-platgame/",
#   connection: "Astro Platformer uses comments to explain the physics loop, platform collision, gravity, moving platforms, spike death, and the route through the level."
# };
#
# function explainAstroConnection(lesson) {
#   console.log(lesson.topic + " in " + lesson.game);
#   console.log("Evidence: " + lesson.codeEvidence);
#   console.log(lesson.connection);
# }
#
# explainAstroConnection(astroLesson);
