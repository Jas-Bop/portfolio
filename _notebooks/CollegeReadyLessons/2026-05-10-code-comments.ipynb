# %% [raw]
# ---
# layout: post
# categories: [CSSE JavaScript]
# microblog: true
# codemirror: true
# title: Comments Lesson
# description: Learn how to explain classes and methods with comments and identify comments in the code.
# permalink: /college-ready/code-comments
# ---

# %% [markdown]
# ## Comments Lesson
#
# Comments Lesson focuses on this skill: **Explain classes and methods with comments**
#
# When you review your project, you should be able to point to **comments in the code** as evidence.

# %% [markdown]
# ## Why Comments Lesson matters
#
# - This helps show that you can explain classes and methods with comments.
# - A reviewer can verify it by checking comments in the code.
# - The example below gives you a small starting point before you connect the idea to your own game.

# %%
# %%js
#
# // CODE_RUNNER: Comments Lesson - practice the idea below.
#
# // Goal: Explain classes and methods with comments
# // Look for: comments in the code
#
# const lesson = {
#   topic: "Comments",
#   evidence: "comments in the code",
#   complete: false
# };
#
# function explainLesson(item) {
#   console.log(item.topic + ": " + item.evidence);
# }
#
# explainLesson(lesson);

# %% [markdown]
# ## Homework

# %%
# %%js
#
# // CODE_RUNNER: Homework - make your own example for Comments Lesson.
#
# // TODO: Write code that shows this skill:
# // Explain classes and methods with comments
#
# console.log("Add your own example here.");
