# %% [raw]
# ---
# layout: post
# categories: [CSSE JavaScript]
# microblog: true
# codemirror: true
# title: Nested If Lesson
# description: Learn what Nested conditions means, how it works in the Astro Platformer game, and how to practice it with a small homework task.
# permalink: /college-ready/nested-conditions
# ---

# %% [markdown]
# ## Nested If Lesson
#
# ### What it is
#
# A nested condition is an if statement inside another if statement. It is used when one question only matters after another question is already true.
#
# ### How it connects to our Astro Platformer
#
# Astro Platformer can use nested conditions for checks like: if the player is alive, then check whether they touched spikes, coins, or the flag.
#
# Evidence to check: `_projects/games/astronaut-platformer-game/levels/astroplatformer.js`, the playable page `/astro-platgame/`, and the gravity write-up `/gravity_blog`.

# %% [markdown]
# ## Why this matters in Astro Platformer
#
# - First check that the game is not over; inside that, check whether the astronaut reached the goal.
# - This lesson is not separate from the project; it is a way to explain one part of our Astro Platformer game.
# - A reviewer should be able to connect this topic back to the actual game code, gameplay, or documentation.

# %%
# %%js
#
# // CODE_RUNNER: Nested If Lesson - Astro Platformer connection.
#
# const astroLesson = {
#   game: "Astro Platformer",
#   topic: "Nested conditions",
#   codeEvidence: "_projects/games/astronaut-platformer-game/levels/astroplatformer.js",
#   playablePage: "/astro-platgame/",
#   connection: "Astro Platformer can use nested conditions for checks like: if the player is alive, then check whether they touched spikes, coins, or the flag."
# };
#
# function explainAstroConnection(lesson) {
#   console.log(lesson.topic + " in " + lesson.game);
#   console.log("Evidence: " + lesson.codeEvidence);
#   console.log(lesson.connection);
# }
#
# explainAstroConnection(astroLesson);

# %% [markdown]
# ## Homework
#
# Write a two-level nested condition for the Astro Platformer, using alive/dead first and a gameplay event second.
#
# Keep it small: write 2-3 sentences or fill in the starter code below. Your answer should mention **Astro Platformer** and one specific file, feature, variable, or gameplay moment.

# %%
# %%js
#
# // CODE_RUNNER: Homework - connect Nested conditions back to Astro Platformer.
#
# const homework = {
#   game: "Astro Platformer",
#   topic: "Nested conditions",
#   fileToCheck: "_projects/games/astronaut-platformer-game/levels/astroplatformer.js",
#   task: "Write a two-level nested condition for the Astro Platformer, using alive/dead first and a gameplay event second.",
#   yourAnswer: "Fill in the inner condition with a real platformer event like coin, spike, or flag."
# };
#
# console.log("Homework topic: " + homework.topic);
# console.log("Task: " + homework.task);
# console.log("My answer: " + homework.yourAnswer);
