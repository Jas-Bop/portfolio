# %% [raw]
# ---
# layout: post
# categories: [CSSE JavaScript]
# microblog: true
# codemirror: true
# title: Nested If Lesson
# description: Learn how to use one condition inside another condition and identify nested if statements.
# permalink: /college-ready/nested-conditions
# ---

# %% [markdown]
# ## Nested If Lesson
#
# Nested If Lesson focuses on this skill: **Use one condition inside another condition**
#
# When you review your project, you should be able to point to **nested if statements** as evidence.

# %% [markdown]
# ## Why Nested If Lesson matters
#
# - This helps show that you can use one condition inside another condition.
# - A reviewer can verify it by checking nested if statements.
# - The example below gives you a small starting point before you connect the idea to your own game.

# %%
# %%js
#
# // CODE_RUNNER: Nested If Lesson - practice the idea below.
#
# // Goal: Use one condition inside another condition
# // Look for: nested if statements
#
# const lesson = {
#   topic: "Nested If",
#   evidence: "nested if statements",
#   complete: false
# };
#
# function explainLesson(item) {
#   console.log(item.topic + ": " + item.evidence);
# }
#
# explainLesson(lesson);

# %% [markdown]
# ## Homework

# %%
# %%js
#
# // CODE_RUNNER: Homework - make your own example for Nested If Lesson.
#
# // TODO: Write code that shows this skill:
# // Use one condition inside another condition
#
# console.log("Add your own example here.");
