# %% [markdown]
# <details class="college-ready-dropdown">
# <summary>Programming Fundamentals</summary>
#
# <details class="college-ready-subdropdown">
# <summary>Nested Conditions</summary>
#
# Nested conditions place one decision inside another. The inner decision runs only after the outer decision has already passed.
#
# <pre><code class="language-javascript">let isMember = true;
# let points = 140;
#
# if (isMember) {
#   if (points &gt;= 100) {
#     console.log("Reward unlocked");
#   }
# }</code></pre>
#
# </details>
# </details>
