# %% [markdown]
# <details class="college-ready-dropdown">
# <summary>Debugging and Testing</summary>
#
# <details class="college-ready-subdropdown">
# <summary>Gameplay Testing</summary>
#
# Gameplay testing checks that an interactive game behaves correctly, including controls, scoring, feedback, win states, and reset behavior.
#
# <pre><code class="language-javascript">const test = { name: "Start button works", passed: true };</code></pre>
#
# </details>
# </details>
