# %% [raw]
# ---
# layout: post
# categories: [CSSE JavaScript]
# microblog: true
# codemirror: true
# title: Gameplay Testing Lesson
# description: Learn what Gameplay testing means, how it works in the Astro Platformer game.
# permalink: /college-ready/gameplay-testing
# ---

# %% [markdown]
# ## Gameplay Testing Lesson
#
# ### What it is
#
# Gameplay testing means playing the game on purpose to check whether the features work the way players expect.
#
# ### How it connects to our games
#
# Astro Platformer needs gameplay testing for jumping, falling, moving platforms, spikes, coins, lives, the flag, and leaderboard behavior.
#
# Evidence to check: `_projects/games/astronaut-platformer-game/levels/astroplatformer.js`, the playable page `/astro-platgame/`, and the gravity write-up `/gravity_blog`.

# %% [markdown]
# ## Why it matters for all lessons
#
# - A good test plays from the start to the flag and also tries mistakes like touching spikes or falling.
# - This lesson is not separate from the project; it is a way to explain one part of our Astro Platformer game.
# - A reviewer should be able to connect this topic back to the actual game code, gameplay, or documentation.

# %%
# %%js
#
# // CODE_RUNNER: Gameplay Testing Lesson - Astro Platformer connection.
#
# const astroLesson = {
#   game: "Astro Platformer",
#   topic: "Gameplay testing",
#   codeEvidence: "_projects/games/astronaut-platformer-game/levels/astroplatformer.js",
#   playablePage: "/astro-platgame/",
#   connection: "Astro Platformer needs gameplay testing for jumping, falling, moving platforms, spikes, coins, lives, the flag, and leaderboard behavior."
# };
#
# function explainAstroConnection(lesson) {
#   console.log(lesson.topic + " in " + lesson.game);
#   console.log("Evidence: " + lesson.codeEvidence);
#   console.log(lesson.connection);
# }
#
# explainAstroConnection(astroLesson);
