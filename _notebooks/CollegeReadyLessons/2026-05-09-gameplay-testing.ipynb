# %% [raw]
# ---
# layout: post
# categories: [CSSE JavaScript]
# microblog: true
# codemirror: true
# title: Gameplay Testing Lesson
# description: Learn how to play the game and check the main features and identify a full playthrough.
# permalink: /college-ready/gameplay-testing
# ---

# %% [markdown]
# ## Gameplay Testing Lesson
#
# Gameplay Testing Lesson focuses on this skill: **Play the game and check the main features**
#
# When you review your project, you should be able to point to **a full playthrough** as evidence.

# %% [markdown]
# ## Why Gameplay Testing Lesson matters
#
# - This helps show that you can play the game and check the main features.
# - A reviewer can verify it by checking a full playthrough.
# - The example below gives you a small starting point before you connect the idea to your own game.

# %%
# %%js
#
# // CODE_RUNNER: Game Demo - practice the idea below.
#
# // Goal: Play the game and check the main features
# // Look for: a full playthrough
#
# const lesson = {
#   topic: "Game Demo",
#   evidence: "a full playthrough",
#   complete: false
# };
#
# function explainLesson(item) {
#   console.log(item.topic + ": " + item.evidence);
# }
#
# explainLesson(lesson);

# %% [markdown]
# ## Homework

# %%
# %%js
#
# // CODE_RUNNER: Homework - make your own example for Game Demo.
#
# // TODO: Write code that shows this skill:
# // Play the game and check the main features
#
# console.log("Add your own example here.");
