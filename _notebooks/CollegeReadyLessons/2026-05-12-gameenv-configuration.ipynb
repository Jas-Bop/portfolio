# %% [markdown]
# <details class="college-ready-dropdown">
# <summary>Browser and Game Interaction</summary>
#
# <details class="college-ready-subdropdown">
# <summary>Configuration Objects</summary>
#
# Configuration objects group setup values in one place. They make settings easier to read, change, and pass into other parts of a program.
#
# <pre><code class="language-javascript">const appConfig = { appName: "Study Tracker", maxAssignments: 20 };</code></pre>
#
# </details>
# </details>
