# %% [raw]
# ---
# layout: post
# categories: [CSSE JavaScript]
# microblog: true
# codemirror: true
# title: Game Setup Lesson
# description: Learn what Game environment configuration means, how it works in the Astro Platformer game.
# permalink: /college-ready/gameenv-configuration
# ---

# %% [markdown]
# ## Game Setup Lesson
#
# ### What it is
#
# Game environment configuration is the setup data that tells the game engine where files are, what levels exist, and which services to use.
#
# ### How it connects to our Astro Platformer
#
# The Astro Platformer page creates an environment with path, gameName, API URIs, gameContainer, level classes, and leaderboard settings.
#
# Evidence to check: `_projects/games/astronaut-platformer-game/levels/astroplatformer.js`, the playable page `/astro-platgame/`, and the gravity write-up `/gravity_blog`.

# %% [markdown]
# ## Why this matters in Astro Platformer
#
# - The gameName "astronaut-platformer-game" connects the engine to this project.
# - This lesson is not separate from the project; it is a way to explain one part of our Astro Platformer game.
# - A reviewer should be able to connect this topic back to the actual game code, gameplay, or documentation.

# %%
# %%js
#
# // CODE_RUNNER: Game Setup Lesson - Astro Platformer connection.
#
# const astroLesson = {
#   game: "Astro Platformer",
#   topic: "Game environment configuration",
#   codeEvidence: "_projects/games/astronaut-platformer-game/levels/astroplatformer.js",
#   playablePage: "/astro-platgame/",
#   connection: "The Astro Platformer page creates an environment with path, gameName, API URIs, gameContainer, level classes, and leaderboard settings."
# };
#
# function explainAstroConnection(lesson) {
#   console.log(lesson.topic + " in " + lesson.game);
#   console.log("Evidence: " + lesson.codeEvidence);
#   console.log(lesson.connection);
# }
#
# explainAstroConnection(astroLesson);
