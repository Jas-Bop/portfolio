# %% [raw]
# ---
# layout: post
# categories: [CSSE JavaScript]
# microblog: true
# codemirror: true
# title: Game Setup Lesson
# description: Learn how to set game size and game settings and identify GameEnv.create() or GameSetup.js.
# permalink: /college-ready/gameenv-configuration
# ---

# %% [markdown]
# ## Game Setup Lesson
#
# Game Setup Lesson focuses on this skill: **Set game size and game settings**
#
# When you review your project, you should be able to point to **GameEnv.create() or GameSetup.js** as evidence.

# %% [markdown]
# ## Why Game Setup Lesson matters
#
# - This helps show that you can set game size and game settings.
# - A reviewer can verify it by checking GameEnv.create() or GameSetup.js.
# - The example below gives you a small starting point before you connect the idea to your own game.

# %%
# %%js
#
# // CODE_RUNNER: Game Setup Lesson - practice the idea below.
#
# // Goal: Set game size and game settings
# // Look for: GameEnv.create() or GameSetup.js
#
# const lesson = {
#   topic: "Game Setup",
#   evidence: "GameEnv.create() or GameSetup.js",
#   complete: false
# };
#
# function explainLesson(item) {
#   console.log(item.topic + ": " + item.evidence);
# }
#
# explainLesson(lesson);

# %% [markdown]
# ## Homework

# %%
# %%js
#
# // CODE_RUNNER: Homework - make your own example for Game Setup Lesson.
#
# // TODO: Write code that shows this skill:
# // Set game size and game settings
#
# console.log("Add your own example here.");
