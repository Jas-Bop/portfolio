# %% [raw]
# ---
# layout: post
# categories: [CSSE JavaScript]
# microblog: true
# codemirror: true
# title: Hit Box Visualization Lesson
# description: Learn how to show hit boxes on screen and identify a hit box demo.
# permalink: /college-ready/hit-box-visualization
# ---

# %% [markdown]
# ## Hit Box Visualization Lesson
#
# Hit Box Visualization Lesson focuses on this skill: **Show hit boxes on screen**
#
# When you review your project, you should be able to point to **a hit box demo** as evidence.

# %% [markdown]
# ## Why Hit Box Visualization Lesson matters
#
# - This helps show that you can show hit boxes on screen.
# - A reviewer can verify it by checking a hit box demo.
# - The example below gives you a small starting point before you connect the idea to your own game.

# %%
# %%js
#
# // CODE_RUNNER: Game Demo - practice the idea below.
#
# // Goal: Show hit boxes on screen
# // Look for: a hit box demo
#
# const lesson = {
#   topic: "Game Demo",
#   evidence: "a hit box demo",
#   complete: false
# };
#
# function explainLesson(item) {
#   console.log(item.topic + ": " + item.evidence);
# }
#
# explainLesson(lesson);

# %% [markdown]
# ## Homework

# %%
# %%js
#
# // CODE_RUNNER: Homework - make your own example for Game Demo.
#
# // TODO: Write code that shows this skill:
# // Show hit boxes on screen
#
# console.log("Add your own example here.");
