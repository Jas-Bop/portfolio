# %% [raw]
# ---
# layout: post
# categories: [CSSE JavaScript]
# microblog: true
# codemirror: true
# title: Hit Box Visualization Lesson
# description: Learn what Hit box visualization means, how it works in the Astro Platformer game, and how to practice it with a small homework task.
# permalink: /college-ready/hit-box-visualization
# ---

# %% [markdown]
# ## Hit Box Visualization Lesson
#
# ### What it is
#
# A hit box is an invisible shape used to detect collisions. Hit box visualization means showing those shapes so collisions are easier to debug.
#
# ### How it connects to our Astro Platformer
#
# Astro Platformer collision checks depend on hit boxes for the astronaut, platforms, spikes, coins, and flag.
#
# Evidence to check: `_projects/games/astronaut-platformer-game/levels/astroplatformer.js`, the playable page `/astro-platgame/`, and the gravity write-up `/gravity_blog`.

# %% [markdown]
# ## Why this matters in Astro Platformer
#
# - Showing spike hit boxes can explain why touching the spike feet area causes death.
# - This lesson is not separate from the project; it is a way to explain one part of our Astro Platformer game.
# - A reviewer should be able to connect this topic back to the actual game code, gameplay, or documentation.

# %%
# %%js
#
# // CODE_RUNNER: Hit Box Visualization Lesson - Astro Platformer connection.
#
# const astroLesson = {
#   game: "Astro Platformer",
#   topic: "Hit box visualization",
#   codeEvidence: "_projects/games/astronaut-platformer-game/levels/astroplatformer.js",
#   playablePage: "/astro-platgame/",
#   connection: "Astro Platformer collision checks depend on hit boxes for the astronaut, platforms, spikes, coins, and flag."
# };
#
# function explainAstroConnection(lesson) {
#   console.log(lesson.topic + " in " + lesson.game);
#   console.log("Evidence: " + lesson.codeEvidence);
#   console.log(lesson.connection);
# }
#
# explainAstroConnection(astroLesson);

# %% [markdown]
# ## Homework
#
# Pick one Astro Platformer object that should have a visible debug hit box and explain why.
#
# Keep it small: write 2-3 sentences or fill in the starter code below. Your answer should mention **Astro Platformer** and one specific file, feature, variable, or gameplay moment.

# %%
# %%js
#
# // CODE_RUNNER: Homework - connect Hit box visualization back to Astro Platformer.
#
# const homework = {
#   game: "Astro Platformer",
#   topic: "Hit box visualization",
#   fileToCheck: "_projects/games/astronaut-platformer-game/levels/astroplatformer.js",
#   task: "Pick one Astro Platformer object that should have a visible debug hit box and explain why.",
#   yourAnswer: "Fill in the object and what collision problem the hit box would help debug."
# };
#
# console.log("Homework topic: " + homework.topic);
# console.log("Task: " + homework.task);
# console.log("My answer: " + homework.yourAnswer);
