# %% [markdown]
# <details class="college-ready-dropdown">
# <summary>Debugging and Testing</summary>
#
# <details class="college-ready-subdropdown">
# <summary>Hit Box Visualization</summary>
#
# Hit box visualization makes invisible collision areas easier to inspect by showing or printing position and size values.
#
# <pre><code class="language-javascript">const hitBox = { x: 20, y: 40, width: 120, height: 35 };</code></pre>
#
# </details>
# </details>
