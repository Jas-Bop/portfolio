# %% [markdown]
# <details class="college-ready-dropdown">
# <summary>Data Types</summary>
#
# <details class="college-ready-subdropdown">
# <summary>Objects and JSON</summary>
#
# Objects group related data with key-value pairs. JSON stores similar structured data as text so it can be saved or transferred.
#
# <pre><code class="language-javascript">const student = { name: "Ava", grade: 9 };
# const jsonText = JSON.stringify(student);</code></pre>
#
# </details>
# </details>
