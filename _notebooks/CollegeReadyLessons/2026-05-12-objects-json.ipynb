# %% [raw]
# ---
# layout: post
# categories: [CSSE JavaScript]
# microblog: true
# codemirror: true
# title: Objects/JSON Lesson
# description: Learn how to use objects to group related data and identify object data in code.
# permalink: /college-ready/objects-json
# ---

# %% [markdown]
# ## Objects/JSON Lesson
#
# Objects/JSON Lesson focuses on this skill: **Use objects to group related data**
#
# When you review your project, you should be able to point to **object data in code** as evidence.

# %% [markdown]
# ## Why Objects/JSON Lesson matters
#
# - This helps show that you can use objects to group related data.
# - A reviewer can verify it by checking object data in code.
# - The example below gives you a small starting point before you connect the idea to your own game.

# %%
# %%js
#
# // CODE_RUNNER: Objects/JSON Lesson - practice the idea below.
#
# // Goal: Use objects to group related data
# // Look for: object data in code
#
# const lesson = {
#   topic: "Objects/JSON",
#   evidence: "object data in code",
#   complete: false
# };
#
# function explainLesson(item) {
#   console.log(item.topic + ": " + item.evidence);
# }
#
# explainLesson(lesson);

# %% [markdown]
# ## Homework

# %%
# %%js
#
# // CODE_RUNNER: Homework - make your own example for Objects/JSON Lesson.
#
# // TODO: Write code that shows this skill:
# // Use objects to group related data
#
# console.log("Add your own example here.");
