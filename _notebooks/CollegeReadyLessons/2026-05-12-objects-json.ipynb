# %% [raw]
# ---
# layout: post
# categories: [CSSE JavaScript]
# microblog: true
# codemirror: true
# title: Objects/JSON Lesson
# description: Learn what Objects and JSON means, how it works in the Astro Platformer game.
# permalink: /college-ready/objects-json
# ---

# %% [markdown]
# ## Objects/JSON Lesson
#
# ### What it is
#
# An object groups related data using key/value pairs. JSON is a text format that looks like objects and is often used to send data.
#
# ### How it connects to our games
#
# Astro Platformer uses objects for player start, platform data, coin data, environment settings, and API-style saved stats.
#
# Evidence to check: `_projects/games/astronaut-platformer-game/levels/astroplatformer.js`, the playable page `/astro-platgame/`, and the gravity write-up `/gravity_blog`.

# %% [markdown]
# ## Why it matters for all lessons
#
# - A platform object can store id, x, y, width, height, and color in one place.
# - This lesson is not separate from the project; it is a way to explain one part of our Astro Platformer game.
# - A reviewer should be able to connect this topic back to the actual game code, gameplay, or documentation.

# %%
# %%js
#
# // CODE_RUNNER: Objects/JSON Lesson - Astro Platformer connection.
#
# const astroLesson = {
#   game: "Astro Platformer",
#   topic: "Objects and JSON",
#   codeEvidence: "_projects/games/astronaut-platformer-game/levels/astroplatformer.js",
#   playablePage: "/astro-platgame/",
#   connection: "Astro Platformer uses objects for player start, platform data, coin data, environment settings, and API-style saved stats."
# };
#
# function explainAstroConnection(lesson) {
#   console.log(lesson.topic + " in " + lesson.game);
#   console.log("Evidence: " + lesson.codeEvidence);
#   console.log(lesson.connection);
# }
#
# explainAstroConnection(astroLesson);
