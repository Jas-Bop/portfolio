# %% [raw]
# ---
# layout: post
# categories: [CSSE JavaScript]
# microblog: true
# codemirror: true
# title: String Operations Lesson
# description: Learn how to join text together in code and identify template strings or + with text.
# permalink: /college-ready/string-operations
# ---

# %% [markdown]
# ## String Operations Lesson
#
# String Operations Lesson focuses on this skill: **Join text together in code**
#
# When you review your project, you should be able to point to **template strings or + with text** as evidence.

# %% [markdown]
# ## Why String Operations Lesson matters
#
# - This helps show that you can join text together in code.
# - A reviewer can verify it by checking template strings or + with text.
# - The example below gives you a small starting point before you connect the idea to your own game.

# %%
# %%js
#
# // CODE_RUNNER: String Operations Lesson - practice the idea below.
#
# // Goal: Join text together in code
# // Look for: template strings or + with text
#
# const lesson = {
#   topic: "String Operations",
#   evidence: "template strings or + with text",
#   complete: false
# };
#
# function explainLesson(item) {
#   console.log(item.topic + ": " + item.evidence);
# }
#
# explainLesson(lesson);

# %% [markdown]
# ## Homework

# %%
# %%js
#
# // CODE_RUNNER: Homework - make your own example for String Operations Lesson.
#
# // TODO: Write code that shows this skill:
# // Join text together in code
#
# console.log("Add your own example here.");
