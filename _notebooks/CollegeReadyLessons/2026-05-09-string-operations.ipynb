# %% [markdown]
# <details class="college-ready-dropdown">
# <summary>Expressions and Operations</summary>
#
# <details class="college-ready-subdropdown">
# <summary>String Operations</summary>
#
# String operations combine, inspect, and transform text. They are used to build dynamic messages and format output.
#
# <pre><code class="language-javascript">let name = "Ava";
# let message = "Hello, " + name;</code></pre>
#
# </details>
# </details>
