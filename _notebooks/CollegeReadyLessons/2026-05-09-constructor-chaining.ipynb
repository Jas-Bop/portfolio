# %% [raw]
# ---
# layout: post
# categories: [CSSE JavaScript]
# microblog: true
# codemirror: true
# title: Constructors Lesson
# description: Learn what Constructors and super means, how it works in the Astro Platformer game.
# permalink: /college-ready/constructor-chaining
# ---

# %% [markdown]
# ## Constructors Lesson
#
# ### What it is
#
# A constructor sets up a new object. In a child class, super() calls the parent constructor so inherited setup still happens.
#
# ### How it connects to our Astro Platformer
#
# Astro Platformer classes can build from engine classes like Coin, Player, or background helpers, so constructors keep shared setup organized.
#
# Evidence to check: `_projects/games/astronaut-platformer-game/levels/astroplatformer.js`, the playable page `/astro-platgame/`, and the gravity write-up `/gravity_blog`.

# %% [markdown]
# ## Why this matters in Astro Platformer
#
# - A custom coin can reuse the normal Coin setup and then add Astro Platformer behavior.
# - This lesson is not separate from the project; it is a way to explain one part of our Astro Platformer game.
# - A reviewer should be able to connect this topic back to the actual game code, gameplay, or documentation.

# %%
# %%js
#
# // CODE_RUNNER: Constructors Lesson - Astro Platformer connection.
#
# const astroLesson = {
#   game: "Astro Platformer",
#   topic: "Constructors and super",
#   codeEvidence: "_projects/games/astronaut-platformer-game/levels/astroplatformer.js",
#   playablePage: "/astro-platgame/",
#   connection: "Astro Platformer classes can build from engine classes like Coin, Player, or background helpers, so constructors keep shared setup organized."
# };
#
# function explainAstroConnection(lesson) {
#   console.log(lesson.topic + " in " + lesson.game);
#   console.log("Evidence: " + lesson.codeEvidence);
#   console.log(lesson.connection);
# }
#
# explainAstroConnection(astroLesson);
