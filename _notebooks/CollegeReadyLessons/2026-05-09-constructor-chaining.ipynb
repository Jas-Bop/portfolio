# %% [raw]
# ---
# layout: post
# categories: [CSSE JavaScript]
# microblog: true
# codemirror: true
# title: Constructors Lesson
# description: Learn how to call the parent constructor with super() and identify super(...) calls.
# permalink: /college-ready/constructor-chaining
# ---

# %% [markdown]
# ## Constructors Lesson
#
# Constructors Lesson focuses on this skill: **Call the parent constructor with super()**
#
# When you review your project, you should be able to point to **super(...) calls** as evidence.

# %% [markdown]
# ## Why Constructors Lesson matters
#
# - This helps show that you can call the parent constructor with super().
# - A reviewer can verify it by checking super(...) calls.
# - The example below gives you a small starting point before you connect the idea to your own game.

# %%
# %%js
#
# // CODE_RUNNER: Constructors Lesson - practice the idea below.
#
# // Goal: Call the parent constructor with super()
# // Look for: super(...) calls
#
# const lesson = {
#   topic: "Constructors",
#   evidence: "super(...) calls",
#   complete: false
# };
#
# function explainLesson(item) {
#   console.log(item.topic + ": " + item.evidence);
# }
#
# explainLesson(lesson);

# %% [markdown]
# ## Homework

# %%
# %%js
#
# // CODE_RUNNER: Homework - make your own example for Constructors Lesson.
#
# // TODO: Write code that shows this skill:
# // Call the parent constructor with super()
#
# console.log("Add your own example here.");
