# %% [raw]
# ---
# layout: post
# categories: [CSSE JavaScript]
# microblog: true
# codemirror: true
# title: Overriding Lesson
# description: Learn how to change parent methods in a child class and identify update(), draw(), or handleCollision().
# permalink: /college-ready/method-overriding
# ---

# %% [markdown]
# ## Overriding Lesson
#
# Overriding Lesson focuses on this skill: **Change parent methods in a child class**
#
# When you review your project, you should be able to point to **update(), draw(), or handleCollision()** as evidence.

# %% [markdown]
# ## Why Overriding Lesson matters
#
# - This helps show that you can change parent methods in a child class.
# - A reviewer can verify it by checking update(), draw(), or handleCollision().
# - The example below gives you a small starting point before you connect the idea to your own game.

# %%
# %%js
#
# // CODE_RUNNER: Overriding Lesson - practice the idea below.
#
# // Goal: Change parent methods in a child class
# // Look for: update(), draw(), or handleCollision()
#
# const lesson = {
#   topic: "Overriding",
#   evidence: "update(), draw(), or handleCollision()",
#   complete: false
# };
#
# function explainLesson(item) {
#   console.log(item.topic + ": " + item.evidence);
# }
#
# explainLesson(lesson);

# %% [markdown]
# ## Homework

# %%
# %%js
#
# // CODE_RUNNER: Homework - make your own example for Overriding Lesson.
#
# // TODO: Write code that shows this skill:
# // Change parent methods in a child class
#
# console.log("Add your own example here.");
