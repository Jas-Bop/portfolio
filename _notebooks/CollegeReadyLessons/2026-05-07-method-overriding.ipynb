# %% [raw]
# ---
# layout: post
# categories: [CSSE JavaScript]
# microblog: true
# codemirror: true
# title: Overriding Lesson
# description: Learn what Method overriding means, how it works in the Astro Platformer game, and how to practice it with a small homework task.
# permalink: /college-ready/method-overriding
# ---

# %% [markdown]
# ## Overriding Lesson
#
# ### What it is
#
# Method overriding means a child class replaces a method it inherited from a parent class with its own version.
#
# ### How it connects to our Astro Platformer
#
# Astro Platformer uses this idea when FixedPlatformerCoin changes how a normal Coin updates and collects so coins fit this level better.
#
# Evidence to check: `_projects/games/astronaut-platformer-game/levels/astroplatformer.js`, the playable page `/astro-platgame/`, and the gravity write-up `/gravity_blog`.

# %% [markdown]
# ## Why this matters in Astro Platformer
#
# - The custom collect method keeps a coin from being collected twice and then fades it out.
# - This lesson is not separate from the project; it is a way to explain one part of our Astro Platformer game.
# - A reviewer should be able to connect this topic back to the actual game code, gameplay, or documentation.

# %%
# %%js
#
# // CODE_RUNNER: Overriding Lesson - Astro Platformer connection.
#
# const astroLesson = {
#   game: "Astro Platformer",
#   topic: "Method overriding",
#   codeEvidence: "_projects/games/astronaut-platformer-game/levels/astroplatformer.js",
#   playablePage: "/astro-platgame/",
#   connection: "Astro Platformer uses this idea when FixedPlatformerCoin changes how a normal Coin updates and collects so coins fit this level better."
# };
#
# function explainAstroConnection(lesson) {
#   console.log(lesson.topic + " in " + lesson.game);
#   console.log("Evidence: " + lesson.codeEvidence);
#   console.log(lesson.connection);
# }
#
# explainAstroConnection(astroLesson);

# %% [markdown]
# ## Homework
#
# Explain why FixedPlatformerCoin needs its own collect behavior instead of only using the default Coin behavior.
#
# Keep it small: write 2-3 sentences or fill in the starter code below. Your answer should mention **Astro Platformer** and one specific file, feature, variable, or gameplay moment.

# %%
# %%js
#
# // CODE_RUNNER: Homework - connect Method overriding back to Astro Platformer.
#
# const homework = {
#   game: "Astro Platformer",
#   topic: "Method overriding",
#   fileToCheck: "_projects/games/astronaut-platformer-game/levels/astroplatformer.js",
#   task: "Explain why FixedPlatformerCoin needs its own collect behavior instead of only using the default Coin behavior.",
#   yourAnswer: "Write one reason the Astro Platformer coin override is useful."
# };
#
# console.log("Homework topic: " + homework.topic);
# console.log("Task: " + homework.task);
# console.log("My answer: " + homework.yourAnswer);
