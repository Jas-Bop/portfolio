# %% [markdown]
# <details class="college-ready-dropdown">
# <summary>Data Types</summary>
#
# <details class="college-ready-subdropdown">
# <summary>Arrays</summary>
#
# Arrays store multiple values in one ordered list. Each item has an index, and loops can process each item in order.
#
# <pre><code class="language-javascript">const scores = [88, 92, 75, 100];
# console.log(scores[0]);</code></pre>
#
# </details>
# </details>
