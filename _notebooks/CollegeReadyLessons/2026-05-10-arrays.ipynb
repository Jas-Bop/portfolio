# %% [raw]
# ---
# layout: post
# categories: [CSSE JavaScript]
# microblog: true
# codemirror: true
# title: Arrays Lesson
# description: Learn how to use arrays to hold groups of things and identify array code.
# permalink: /college-ready/arrays
# ---

# %% [markdown]
# ## Arrays Lesson
#
# Arrays Lesson focuses on this skill: **Use arrays to hold groups of things**
#
# When you review your project, you should be able to point to **array code** as evidence.

# %% [markdown]
# ## Why Arrays Lesson matters
#
# - This helps show that you can use arrays to hold groups of things.
# - A reviewer can verify it by checking array code.
# - The example below gives you a small starting point before you connect the idea to your own game.

# %%
# %%js
#
# // CODE_RUNNER: Arrays Lesson - practice the idea below.
#
# // Goal: Use arrays to hold groups of things
# // Look for: array code
#
# const lesson = {
#   topic: "Arrays",
#   evidence: "array code",
#   complete: false
# };
#
# function explainLesson(item) {
#   console.log(item.topic + ": " + item.evidence);
# }
#
# explainLesson(lesson);

# %% [markdown]
# ## Homework

# %%
# %%js
#
# // CODE_RUNNER: Homework - make your own example for Arrays Lesson.
#
# // TODO: Write code that shows this skill:
# // Use arrays to hold groups of things
#
# console.log("Add your own example here.");
