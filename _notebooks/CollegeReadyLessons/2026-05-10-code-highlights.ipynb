# %% [raw]
# ---
# layout: post
# categories: [CSSE JavaScript]
# microblog: true
# codemirror: true
# title: Code Highlights Lesson
# description: Learn what Code highlights means, how it works in the Astro Platformer game, and how to practice it with a small homework task.
# permalink: /college-ready/code-highlights
# ---

# %% [markdown]
# ## Code Highlights Lesson
#
# ### What it is
#
# Code highlights are selected pieces of code with notes explaining why they matter.
#
# ### How it connects to our Astro Platformer
#
# Astro Platformer code highlights can point classmates to the most important parts of gravity, jumping, collision, coins, and winning.
#
# Evidence to check: `_projects/games/astronaut-platformer-game/levels/astroplatformer.js`, the playable page `/astro-platgame/`, and the gravity write-up `/gravity_blog`.

# %% [markdown]
# ## Why this matters in Astro Platformer
#
# - Highlighting the gravity line helps show how falling starts after each jump.
# - This lesson is not separate from the project; it is a way to explain one part of our Astro Platformer game.
# - A reviewer should be able to connect this topic back to the actual game code, gameplay, or documentation.

# %%
# %%js
#
# // CODE_RUNNER: Code Highlights Lesson - Astro Platformer connection.
#
# const astroLesson = {
#   game: "Astro Platformer",
#   topic: "Code highlights",
#   codeEvidence: "_projects/games/astronaut-platformer-game/levels/astroplatformer.js",
#   playablePage: "/astro-platgame/",
#   connection: "Astro Platformer code highlights can point classmates to the most important parts of gravity, jumping, collision, coins, and winning."
# };
#
# function explainAstroConnection(lesson) {
#   console.log(lesson.topic + " in " + lesson.game);
#   console.log("Evidence: " + lesson.codeEvidence);
#   console.log(lesson.connection);
# }
#
# explainAstroConnection(astroLesson);

# %% [markdown]
# ## Homework
#
# Choose one Astro Platformer line or small block worth highlighting and explain why.
#
# Keep it small: write 2-3 sentences or fill in the starter code below. Your answer should mention **Astro Platformer** and one specific file, feature, variable, or gameplay moment.

# %%
# %%js
#
# // CODE_RUNNER: Homework - connect Code highlights back to Astro Platformer.
#
# const homework = {
#   game: "Astro Platformer",
#   topic: "Code highlights",
#   fileToCheck: "_projects/games/astronaut-platformer-game/levels/astroplatformer.js",
#   task: "Choose one Astro Platformer line or small block worth highlighting and explain why.",
#   yourAnswer: "Fill in the feature and why it should be highlighted."
# };
#
# console.log("Homework topic: " + homework.topic);
# console.log("Task: " + homework.task);
# console.log("My answer: " + homework.yourAnswer);
