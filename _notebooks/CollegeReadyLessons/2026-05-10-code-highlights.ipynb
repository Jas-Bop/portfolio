# %% [raw]
# ---
# layout: post
# categories: [CSSE JavaScript]
# microblog: true
# codemirror: true
# title: Code Highlights Lesson
# description: Learn how to explain important code examples and identify highlighted code with notes.
# permalink: /college-ready/code-highlights
# ---

# %% [markdown]
# ## Code Highlights Lesson
#
# Code Highlights Lesson focuses on this skill: **Explain important code examples**
#
# When you review your project, you should be able to point to **highlighted code with notes** as evidence.

# %% [markdown]
# ## Why Code Highlights Lesson matters
#
# - This helps show that you can explain important code examples.
# - A reviewer can verify it by checking highlighted code with notes.
# - The example below gives you a small starting point before you connect the idea to your own game.

# %%
# %%js
#
# // CODE_RUNNER: Code Highlights Page - practice the idea below.
#
# // Goal: Explain important code examples
# // Look for: highlighted code with notes
#
# const lesson = {
#   topic: "Code Highlights Page",
#   evidence: "highlighted code with notes",
#   complete: false
# };
#
# function explainLesson(item) {
#   console.log(item.topic + ": " + item.evidence);
# }
#
# explainLesson(lesson);

# %% [markdown]
# ## Homework

# %%
# %%js
#
# // CODE_RUNNER: Homework - make your own example for Code Highlights Page.
#
# // TODO: Write code that shows this skill:
# // Explain important code examples
#
# console.log("Add your own example here.");
