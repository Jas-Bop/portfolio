# %% [markdown]
# <details class="college-ready-dropdown">
# <summary>Documentation</summary>
#
# <details class="college-ready-subdropdown">
# <summary>Code Highlights</summary>
#
# Code highlights select important lines and explain why they matter. They help readers focus on meaningful logic.
#
# <pre><code class="language-javascript">const highlight = { line: "score += points", explanation: "adds points" };</code></pre>
#
# </details>
# </details>
