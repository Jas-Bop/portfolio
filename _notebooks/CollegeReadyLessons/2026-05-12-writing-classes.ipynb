# %% [raw]
# ---
# layout: post
# categories: [CSSE JavaScript]
# microblog: true
# codemirror: true
# title: Classes Lesson
# description: Learn what Classes means, how it works in the Astro Platformer game, and how to practice it with a small homework task.
# permalink: /college-ready/writing-classes
# ---

# %% [markdown]
# ## Classes Lesson
#
# ### What it is
#
# A class is a blueprint for creating objects with shared data and behavior.
#
# ### How it connects to our Astro Platformer
#
# Astro Platformer uses classes to organize the level and custom objects, such as AstroPlatformer and FixedPlatformerCoin.
#
# Evidence to check: `_projects/games/astronaut-platformer-game/levels/astroplatformer.js`, the playable page `/astro-platgame/`, and the gravity write-up `/gravity_blog`.

# %% [markdown]
# ## Why this matters in Astro Platformer
#
# - The AstroPlatformer class keeps the level setup, physics state, input, and update behavior together.
# - This lesson is not separate from the project; it is a way to explain one part of our Astro Platformer game.
# - A reviewer should be able to connect this topic back to the actual game code, gameplay, or documentation.

# %%
# %%js
#
# // CODE_RUNNER: Classes Lesson - Astro Platformer connection.
#
# const astroLesson = {
#   game: "Astro Platformer",
#   topic: "Classes",
#   codeEvidence: "_projects/games/astronaut-platformer-game/levels/astroplatformer.js",
#   playablePage: "/astro-platgame/",
#   connection: "Astro Platformer uses classes to organize the level and custom objects, such as AstroPlatformer and FixedPlatformerCoin."
# };
#
# function explainAstroConnection(lesson) {
#   console.log(lesson.topic + " in " + lesson.game);
#   console.log("Evidence: " + lesson.codeEvidence);
#   console.log(lesson.connection);
# }
#
# explainAstroConnection(astroLesson);

# %% [markdown]
# ## Homework
#
# Sketch one class that would fit Astro Platformer, such as a moving platform, laser, hazard, or collectible.
#
# Keep it small: write 2-3 sentences or fill in the starter code below. Your answer should mention **Astro Platformer** and one specific file, feature, variable, or gameplay moment.

# %%
# %%js
#
# // CODE_RUNNER: Homework - connect Classes back to Astro Platformer.
#
# const homework = {
#   game: "Astro Platformer",
#   topic: "Classes",
#   fileToCheck: "_projects/games/astronaut-platformer-game/levels/astroplatformer.js",
#   task: "Sketch one class that would fit Astro Platformer, such as a moving platform, laser, hazard, or collectible.",
#   yourAnswer: "Fill in a class name, two properties, and one method for an Astro Platformer feature."
# };
#
# console.log("Homework topic: " + homework.topic);
# console.log("Task: " + homework.task);
# console.log("My answer: " + homework.yourAnswer);
