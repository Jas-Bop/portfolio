# %% [raw]
# ---
# layout: post
# categories: [CSSE JavaScript]
# microblog: true
# codemirror: true
# title: Classes Lesson
# description: Learn how to make at least 2 custom character classes and identify Player.js, NPC.js, or Enemy.js.
# permalink: /college-ready/writing-classes
# ---

# %% [markdown]
# ## Classes Lesson
#
# Classes Lesson focuses on this skill: **Make at least 2 custom character classes**
#
# When you review your project, you should be able to point to **Player.js, NPC.js, or Enemy.js** as evidence.

# %% [markdown]
# ## Why Classes Lesson matters
#
# - This helps show that you can make at least 2 custom character classes.
# - A reviewer can verify it by checking Player.js, NPC.js, or Enemy.js.
# - The example below gives you a small starting point before you connect the idea to your own game.

# %%
# %%js
#
# // CODE_RUNNER: Classes Lesson - practice the idea below.
#
# // Goal: Make at least 2 custom character classes
# // Look for: Player.js, NPC.js, or Enemy.js
#
# const lesson = {
#   topic: "Classes",
#   evidence: "Player.js, NPC.js, or Enemy.js",
#   complete: false
# };
#
# function explainLesson(item) {
#   console.log(item.topic + ": " + item.evidence);
# }
#
# explainLesson(lesson);

# %% [markdown]
# ## Homework

# %%
# %%js
#
# // CODE_RUNNER: Homework - make your own example for Classes Lesson.
#
# // TODO: Write code that shows this skill:
# // Make at least 2 custom character classes
#
# console.log("Add your own example here.");
