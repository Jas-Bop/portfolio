# %% [markdown]
# <details class="college-ready-dropdown">
# <summary>Browser and Game Interaction</summary>
#
# <details class="college-ready-subdropdown">
# <summary>Canvas Rendering</summary>
#
# Canvas rendering draws graphics onto a canvas using JavaScript commands. Drawing order matters because later drawings can cover earlier ones.
#
# <pre><code class="language-javascript">const frameSteps = ["clear", "background", "player", "ui"];
# frameSteps.forEach(step =&gt; console.log(step));</code></pre>
#
# </details>
# </details>
