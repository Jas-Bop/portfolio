# %% [raw]
# ---
# layout: post
# categories: [CSSE JavaScript]
# microblog: true
# codemirror: true
# title: Canvas Lesson
# description: Learn how to draw game parts on the canvas and identify draw() methods.
# permalink: /college-ready/canvas-rendering
# ---

# %% [markdown]
# ## Canvas Lesson
#
# Canvas Lesson focuses on this skill: **Draw game parts on the canvas**
#
# When you review your project, you should be able to point to **draw() methods** as evidence.

# %% [markdown]
# ## Why Canvas Lesson matters
#
# - This helps show that you can draw game parts on the canvas.
# - A reviewer can verify it by checking draw() methods.
# - The example below gives you a small starting point before you connect the idea to your own game.

# %%
# %%js
#
# // CODE_RUNNER: Canvas Lesson - practice the idea below.
#
# // Goal: Draw game parts on the canvas
# // Look for: draw() methods
#
# const lesson = {
#   topic: "Canvas",
#   evidence: "draw() methods",
#   complete: false
# };
#
# function explainLesson(item) {
#   console.log(item.topic + ": " + item.evidence);
# }
#
# explainLesson(lesson);

# %% [markdown]
# ## Homework

# %%
# %%js
#
# // CODE_RUNNER: Homework - make your own example for Canvas Lesson.
#
# // TODO: Write code that shows this skill:
# // Draw game parts on the canvas
#
# console.log("Add your own example here.");
