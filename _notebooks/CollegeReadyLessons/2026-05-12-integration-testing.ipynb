# %% [raw]
# ---
# layout: post
# categories: [CSSE JavaScript]
# microblog: true
# codemirror: true
# title: API Testing Lesson
# description: Learn what Integration testing means, how it works in the Astro Platformer game, and how to practice it with a small homework task.
# permalink: /college-ready/integration-testing
# ---

# %% [markdown]
# ## API Testing Lesson
#
# ### What it is
#
# Integration testing checks whether multiple parts of a project work together, not just whether one small function works alone.
#
# ### How it connects to our Astro Platformer
#
# Astro Platformer needs integration testing because movement, collision, coins, localStorage, API settings, and leaderboard display all interact.
#
# Evidence to check: `_projects/games/astronaut-platformer-game/levels/astroplatformer.js`, the playable page `/astro-platgame/`, and the gravity write-up `/gravity_blog`.

# %% [markdown]
# ## Why this matters in Astro Platformer
#
# - A full test can collect a coin, save the stat, avoid spikes, reach the flag, and confirm the game still responds.
# - This lesson is not separate from the project; it is a way to explain one part of our Astro Platformer game.
# - A reviewer should be able to connect this topic back to the actual game code, gameplay, or documentation.

# %%
# %%js
#
# // CODE_RUNNER: API Testing Lesson - Astro Platformer connection.
#
# const astroLesson = {
#   game: "Astro Platformer",
#   topic: "Integration testing",
#   codeEvidence: "_projects/games/astronaut-platformer-game/levels/astroplatformer.js",
#   playablePage: "/astro-platgame/",
#   connection: "Astro Platformer needs integration testing because movement, collision, coins, localStorage, API settings, and leaderboard display all interact."
# };
#
# function explainAstroConnection(lesson) {
#   console.log(lesson.topic + " in " + lesson.game);
#   console.log("Evidence: " + lesson.codeEvidence);
#   console.log(lesson.connection);
# }
#
# explainAstroConnection(astroLesson);

# %% [markdown]
# ## Homework
#
# Write one integration test that combines at least two Astro Platformer systems.
#
# Keep it small: write 2-3 sentences or fill in the starter code below. Your answer should mention **Astro Platformer** and one specific file, feature, variable, or gameplay moment.

# %%
# %%js
#
# // CODE_RUNNER: Homework - connect Integration testing back to Astro Platformer.
#
# const homework = {
#   game: "Astro Platformer",
#   topic: "Integration testing",
#   fileToCheck: "_projects/games/astronaut-platformer-game/levels/astroplatformer.js",
#   task: "Write one integration test that combines at least two Astro Platformer systems.",
#   yourAnswer: "Fill in the two systems and expected result."
# };
#
# console.log("Homework topic: " + homework.topic);
# console.log("Task: " + homework.task);
# console.log("My answer: " + homework.yourAnswer);
