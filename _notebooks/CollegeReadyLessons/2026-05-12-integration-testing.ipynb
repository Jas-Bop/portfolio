# %% [raw]
# ---
# layout: post
# categories: [CSSE JavaScript]
# microblog: true
# codemirror: true
# title: API Testing Lesson
# description: Learn how to test live API features and identify saved scores or AI responses.
# permalink: /college-ready/integration-testing
# ---

# %% [markdown]
# ## API Testing Lesson
#
# API Testing Lesson focuses on this skill: **Test live API features**
#
# When you review your project, you should be able to point to **saved scores or AI responses** as evidence.

# %% [markdown]
# ## Why API Testing Lesson matters
#
# - This helps show that you can test live API features.
# - A reviewer can verify it by checking saved scores or AI responses.
# - The example below gives you a small starting point before you connect the idea to your own game.

# %%
# %%js
#
# // CODE_RUNNER: API Testing Lesson - practice the idea below.
#
# // Goal: Test live API features
# // Look for: saved scores or AI responses
#
# const lesson = {
#   topic: "API Testing",
#   evidence: "saved scores or AI responses",
#   complete: false
# };
#
# function explainLesson(item) {
#   console.log(item.topic + ": " + item.evidence);
# }
#
# explainLesson(lesson);

# %% [markdown]
# ## Homework

# %%
# %%js
#
# // CODE_RUNNER: Homework - make your own example for API Testing Lesson.
#
# // TODO: Write code that shows this skill:
# // Test live API features
#
# console.log("Add your own example here.");
