# %% [markdown]
# <details class="college-ready-dropdown">
# <summary>Debugging and Testing</summary>
#
# <details class="college-ready-subdropdown">
# <summary>Integration Testing</summary>
#
# Integration testing checks whether multiple connected parts of a program work together as a complete workflow.
#
# <pre><code class="language-javascript">const passed = true &amp;&amp; true &amp;&amp; true;</code></pre>
#
# </details>
# </details>
