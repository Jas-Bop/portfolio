# %% [raw]
# ---
# layout: post
# categories: [CSSE JavaScript]
# microblog: true
# codemirror: true
# title: Boolean Operators Lesson
# description: Learn how to combine true/false checks and identify &&, ||, or !.
# permalink: /college-ready/boolean-expressions
# ---

# %% [markdown]
# ## Boolean Operators Lesson
#
# Boolean Operators Lesson focuses on this skill: **Combine true/false checks**
#
# When you review your project, you should be able to point to **&&, ||, or !** as evidence.

# %% [markdown]
# ## Why Boolean Operators Lesson matters
#
# - This helps show that you can combine true/false checks.
# - A reviewer can verify it by checking &&, ||, or !.
# - The example below gives you a small starting point before you connect the idea to your own game.

# %%
# %%js
#
# // CODE_RUNNER: Boolean Operators Lesson - practice the idea below.
#
# // Goal: Combine true/false checks
# // Look for: &&, ||, or !
#
# const lesson = {
#   topic: "Boolean Operators",
#   evidence: "&&, ||, or !",
#   complete: false
# };
#
# function explainLesson(item) {
#   console.log(item.topic + ": " + item.evidence);
# }
#
# explainLesson(lesson);

# %% [markdown]
# ## Homework

# %%
# %%js
#
# // CODE_RUNNER: Homework - make your own example for Boolean Operators Lesson.
#
# // TODO: Write code that shows this skill:
# // Combine true/false checks
#
# console.log("Add your own example here.");
