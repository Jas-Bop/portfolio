# %% [raw]
# ---
# layout: post
# categories: [CSSE JavaScript]
# microblog: true
# codemirror: true
# title: Boolean Operators Lesson
# description: Learn what Boolean expressions means, how it works in the Astro Platformer game, and how to practice it with a small homework task.
# permalink: /college-ready/boolean-expressions
# ---

# %% [markdown]
# ## Boolean Operators Lesson
#
# ### What it is
#
# A boolean expression is a true/false test. Operators like &&, ||, and ! combine or flip true/false checks.
#
# ### How it connects to our Astro Platformer
#
# Astro Platformer uses boolean expressions when checking input keys, player state, collision overlap, and whether the game should keep updating.
#
# Evidence to check: `_projects/games/astronaut-platformer-game/levels/astroplatformer.js`, the playable page `/astro-platgame/`, and the gravity write-up `/gravity_blog`.

# %% [markdown]
# ## Why this matters in Astro Platformer
#
# - A rule could check that the astronaut is alive && touching a coin before collecting it.
# - This lesson is not separate from the project; it is a way to explain one part of our Astro Platformer game.
# - A reviewer should be able to connect this topic back to the actual game code, gameplay, or documentation.

# %%
# %%js
#
# // CODE_RUNNER: Boolean Operators Lesson - Astro Platformer connection.
#
# const astroLesson = {
#   game: "Astro Platformer",
#   topic: "Boolean expressions",
#   codeEvidence: "_projects/games/astronaut-platformer-game/levels/astroplatformer.js",
#   playablePage: "/astro-platgame/",
#   connection: "Astro Platformer uses boolean expressions when checking input keys, player state, collision overlap, and whether the game should keep updating."
# };
#
# function explainAstroConnection(lesson) {
#   console.log(lesson.topic + " in " + lesson.game);
#   console.log("Evidence: " + lesson.codeEvidence);
#   console.log(lesson.connection);
# }
#
# explainAstroConnection(astroLesson);

# %% [markdown]
# ## Homework
#
# Create one boolean expression for Astro Platformer using &&, ||, or !.
#
# Keep it small: write 2-3 sentences or fill in the starter code below. Your answer should mention **Astro Platformer** and one specific file, feature, variable, or gameplay moment.

# %%
# %%js
#
# // CODE_RUNNER: Homework - connect Boolean expressions back to Astro Platformer.
#
# const homework = {
#   game: "Astro Platformer",
#   topic: "Boolean expressions",
#   fileToCheck: "_projects/games/astronaut-platformer-game/levels/astroplatformer.js",
#   task: "Create one boolean expression for Astro Platformer using &&, ||, or !.",
#   yourAnswer: "Change the expression so it describes a real Astro Platformer rule."
# };
#
# console.log("Homework topic: " + homework.topic);
# console.log("Task: " + homework.task);
# console.log("My answer: " + homework.yourAnswer);
