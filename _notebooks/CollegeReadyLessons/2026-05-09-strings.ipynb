# %% [raw]
# ---
# layout: post
# categories: [CSSE JavaScript]
# microblog: true
# codemirror: true
# title: Strings Lesson
# description: Learn how to use text for names, image paths, or states and identify string values in code.
# permalink: /college-ready/strings
# ---

# %% [markdown]
# ## Strings Lesson
#
# Strings Lesson focuses on this skill: **Use text for names, image paths, or states**
#
# When you review your project, you should be able to point to **string values in code** as evidence.

# %% [markdown]
# ## Why Strings Lesson matters
#
# - This helps show that you can use text for names, image paths, or states.
# - A reviewer can verify it by checking string values in code.
# - The example below gives you a small starting point before you connect the idea to your own game.

# %%
# %%js
#
# // CODE_RUNNER: Strings Lesson - practice the idea below.
#
# // Goal: Use text for names, image paths, or states
# // Look for: string values in code
#
# const lesson = {
#   topic: "Strings",
#   evidence: "string values in code",
#   complete: false
# };
#
# function explainLesson(item) {
#   console.log(item.topic + ": " + item.evidence);
# }
#
# explainLesson(lesson);

# %% [markdown]
# ## Homework

# %%
# %%js
#
# // CODE_RUNNER: Homework - make your own example for Strings Lesson.
#
# // TODO: Write code that shows this skill:
# // Use text for names, image paths, or states
#
# console.log("Add your own example here.");
