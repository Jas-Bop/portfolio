# %% [markdown]
# <details class="college-ready-dropdown">
# <summary>Data Types</summary>
#
# <details class="college-ready-subdropdown">
# <summary>Strings</summary>
#
# Strings store text. They are used for names, messages, labels, file paths, IDs, and any value that should be treated as words instead of math.
#
# <pre><code class="language-javascript">let title = "JavaScript Basics";
# let greeting = "Welcome to " + title;</code></pre>
#
# </details>
# </details>
