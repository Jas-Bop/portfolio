# %% [raw]
# ---
# layout: post
# categories: [CSSE JavaScript]
# microblog: true
# codemirror: true
# title: Browser Data Lesson
# description: Learn what Application debugging means, how it works in the Astro Platformer game.
# permalink: /college-ready/application-debugging
# ---

# %% [markdown]
# ## Browser Data Lesson
#
# ### What it is
#
# Application debugging means using the browser Application tab to inspect stored data like localStorage, cookies, and cache.
#
# ### How it connects to our Astro Platformer
#
# Astro Platformer stores coin or score-related values, so the Application tab can confirm what was saved after gameplay.
#
# Evidence to check: `_projects/games/astronaut-platformer-game/levels/astroplatformer.js`, the playable page `/astro-platgame/`, and the gravity write-up `/gravity_blog`.

# %% [markdown]
# ## Why this matters in Astro Platformer
#
# - If coinsCollected is saved in localStorage, the Application tab can show whether the value changed.
# - This lesson is not separate from the project; it is a way to explain one part of our Astro Platformer game.
# - A reviewer should be able to connect this topic back to the actual game code, gameplay, or documentation.

# %%
# %%js
#
# // CODE_RUNNER: Browser Data Lesson - Astro Platformer connection.
#
# const astroLesson = {
#   game: "Astro Platformer",
#   topic: "Application debugging",
#   codeEvidence: "_projects/games/astronaut-platformer-game/levels/astroplatformer.js",
#   playablePage: "/astro-platgame/",
#   connection: "Astro Platformer stores coin or score-related values, so the Application tab can confirm what was saved after gameplay."
# };
#
# function explainAstroConnection(lesson) {
#   console.log(lesson.topic + " in " + lesson.game);
#   console.log("Evidence: " + lesson.codeEvidence);
#   console.log(lesson.connection);
# }
#
# explainAstroConnection(astroLesson);
