# %% [raw]
# ---
# layout: post
# categories: [CSSE JavaScript]
# microblog: true
# codemirror: true
# title: Browser Data Lesson
# description: Learn how to check saved browser data and identify the Application tab demo.
# permalink: /college-ready/application-debugging
# ---

# %% [markdown]
# ## Browser Data Lesson
#
# Browser Data Lesson focuses on this skill: **Check saved browser data**
#
# When you review your project, you should be able to point to **the Application tab demo** as evidence.

# %% [markdown]
# ## Why Browser Data Lesson matters
#
# - This helps show that you can check saved browser data.
# - A reviewer can verify it by checking the Application tab demo.
# - The example below gives you a small starting point before you connect the idea to your own game.

# %%
# %%js
#
# // CODE_RUNNER: Browser Data Lesson - practice the idea below.
#
# // Goal: Check saved browser data
# // Look for: the Application tab demo
#
# const lesson = {
#   topic: "Browser Data",
#   evidence: "the Application tab demo",
#   complete: false
# };
#
# function explainLesson(item) {
#   console.log(item.topic + ": " + item.evidence);
# }
#
# explainLesson(lesson);

# %% [markdown]
# ## Homework

# %%
# %%js
#
# // CODE_RUNNER: Homework - make your own example for Browser Data Lesson.
#
# // TODO: Write code that shows this skill:
# // Check saved browser data
#
# console.log("Add your own example here.");
