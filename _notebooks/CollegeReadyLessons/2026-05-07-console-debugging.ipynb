# %% [raw]
# ---
# layout: post
# categories: [CSSE JavaScript]
# microblog: true
# codemirror: true
# title: Console Debugging Lesson
# description: Learn how to use console.log to see what the game is doing and identify helpful console logs.
# permalink: /college-ready/console-debugging
# ---

# %% [markdown]
# ## Console Debugging Lesson
#
# Console Debugging Lesson focuses on this skill: **Use console.log to see what the game is doing**
#
# When you review your project, you should be able to point to **helpful console logs** as evidence.

# %% [markdown]
# ## Why Console Debugging Lesson matters
#
# - This helps show that you can use console.log to see what the game is doing.
# - A reviewer can verify it by checking helpful console logs.
# - The example below gives you a small starting point before you connect the idea to your own game.

# %%
# %%js
#
# // CODE_RUNNER: Console Debugging Notes - practice the idea below.
#
# // Goal: Use console.log to see what the game is doing
# // Look for: helpful console logs
#
# const lesson = {
#   topic: "Console Debugging Notes",
#   evidence: "helpful console logs",
#   complete: false
# };
#
# function explainLesson(item) {
#   console.log(item.topic + ": " + item.evidence);
# }
#
# explainLesson(lesson);

# %% [markdown]
# ## Homework

# %%
# %%js
#
# // CODE_RUNNER: Homework - make your own example for Console Debugging Notes.
#
# // TODO: Write code that shows this skill:
# // Use console.log to see what the game is doing
#
# console.log("Add your own example here.");
