# %% [raw]
# ---
# layout: post
# categories: [CSSE JavaScript]
# microblog: true
# codemirror: true
# title: Console Debugging Lesson
# description: Learn what Console debugging means, how it works in the Astro Platformer game.
# permalink: /college-ready/console-debugging
# ---

# %% [markdown]
# ## Console Debugging Lesson
#
# ### What it is
#
# Console debugging means printing messages with console.log so you can see what your code is doing while it runs.
#
# ### How it connects to our games
#
# In Astro Platformer, console messages can help test coin collection, player position, gravity speed, or whether a collision happened.
#
# Evidence to check: `_projects/games/astronaut-platformer-game/levels/astroplatformer.js`, the playable page `/astro-platgame/`, and the gravity write-up `/gravity_blog`.

# %% [markdown]
# ## Why it matters for all lessons
#
# - Logging the coin total after collection helps confirm that localStorage and the HUD are updating.
# - This lesson is not separate from the project; it is a way to explain one part of our Astro Platformer game.
# - A reviewer should be able to connect this topic back to the actual game code, gameplay, or documentation.

# %%
# %%js
#
# // CODE_RUNNER: Console Debugging Lesson - Astro Platformer connection.
#
# const astroLesson = {
#   game: "Astro Platformer",
#   topic: "Console debugging",
#   codeEvidence: "_projects/games/astronaut-platformer-game/levels/astroplatformer.js",
#   playablePage: "/astro-platgame/",
#   connection: "In Astro Platformer, console messages can help test coin collection, player position, gravity speed, or whether a collision happened."
# };
#
# function explainAstroConnection(lesson) {
#   console.log(lesson.topic + " in " + lesson.game);
#   console.log("Evidence: " + lesson.codeEvidence);
#   console.log(lesson.connection);
# }
#
# explainAstroConnection(astroLesson);
