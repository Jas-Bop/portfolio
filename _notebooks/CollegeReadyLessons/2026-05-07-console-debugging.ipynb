# %% [markdown]
# <details class="college-ready-dropdown">
# <summary>Debugging and Testing</summary>
#
# <details class="college-ready-subdropdown">
# <summary>Console Debugging</summary>
#
# Console debugging prints messages while a program runs. It reveals values before and after important changes.
#
# <pre><code class="language-javascript">let total = 0;
# console.log("before", total);
# total += 5;
# console.log("after", total);</code></pre>
#
# </details>
# </details>
