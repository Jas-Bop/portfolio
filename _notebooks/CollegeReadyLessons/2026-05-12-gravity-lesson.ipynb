# %% [markdown]
# <details class="college-ready-dropdown">
# <summary>Browser and Game Interaction</summary>
#
# <details class="college-ready-subdropdown">
# <summary>Gravity in Games</summary>
#
# Gravity in games is usually a number that changes vertical velocity over time. Repeated updates create falling motion.
#
# <pre><code class="language-javascript">let y = 100;
# let velocityY = 0;
# let gravity = 0.8;
# velocityY += gravity;
# y += velocityY;</code></pre>
#
# </details>
# </details>
