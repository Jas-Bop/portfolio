# %% [raw]
# ---
# layout: post
# categories: [CSSE JavaScript]
# microblog: true
# codemirror: true
# title: Gravity Lesson
# description: Learn what Gravity means, how it works in the Astro Platformer game, and how to practice it with a small homework task.
# permalink: /college-ready/gravity-lesson
# ---

# %% [markdown]
# ## Gravity Lesson
#
# ### What it is
#
# Gravity in a platformer is the downward force that pulls the player back toward the ground after jumping or falling.
#
# ### How it connects to our Astro Platformer
#
# Astro Platformer uses gravity, jump force, max fall speed, and platform collision so the astronaut can jump, fall, land, and keep moving through the level.
#
# Evidence to check: `_projects/games/astronaut-platformer-game/levels/astroplatformer.js`, the playable page `/astro-platgame/`, and the gravity write-up `/gravity_blog`.

# %% [markdown]
# ## Why this matters in Astro Platformer
#
# - The level adds gravity to vertical velocity, then checks platforms to decide whether the astronaut should land.
# - This lesson is not separate from the project; it is a way to explain one part of our Astro Platformer game.
# - A reviewer should be able to connect this topic back to the actual game code, gameplay, or documentation.

# %%
# %%js
#
# // CODE_RUNNER: Gravity Lesson - Astro Platformer connection.
#
# const astroLesson = {
#   game: "Astro Platformer",
#   topic: "Gravity",
#   codeEvidence: "_projects/games/astronaut-platformer-game/levels/astroplatformer.js",
#   playablePage: "/astro-platgame/",
#   connection: "Astro Platformer uses gravity, jump force, max fall speed, and platform collision so the astronaut can jump, fall, land, and keep moving through the level."
# };
#
# function explainAstroConnection(lesson) {
#   console.log(lesson.topic + " in " + lesson.game);
#   console.log("Evidence: " + lesson.codeEvidence);
#   console.log(lesson.connection);
# }
#
# explainAstroConnection(astroLesson);

# %% [markdown]
# ## Homework
#
# Explain one part of the Astro Platformer gravity system: gravity, jump force, max fall, or landing collision.
#
# Keep it small: write 2-3 sentences or fill in the starter code below. Your answer should mention **Astro Platformer** and one specific file, feature, variable, or gameplay moment.

# %%
# %%js
#
# // CODE_RUNNER: Homework - connect Gravity back to Astro Platformer.
#
# const homework = {
#   game: "Astro Platformer",
#   topic: "Gravity",
#   fileToCheck: "_projects/games/astronaut-platformer-game/levels/astroplatformer.js",
#   task: "Explain one part of the Astro Platformer gravity system: gravity, jump force, max fall, or landing collision.",
#   yourAnswer: "Choose one gravity variable and explain what happens if it changes."
# };
#
# console.log("Homework topic: " + homework.topic);
# console.log("Task: " + homework.task);
# console.log("My answer: " + homework.yourAnswer);
