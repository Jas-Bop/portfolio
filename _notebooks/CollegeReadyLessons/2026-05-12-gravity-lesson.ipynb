# %% [raw]
# ---
# layout: post
# categories: [CSSE JavaScript]
# microblog: true
# codemirror: true
# title: Gravity Lesson
# description: Learn how to see how gravity works in my platformer game and identify my platformer/gravity lesson.
# permalink: /college-ready/gravity-lesson
# ---

# %% [markdown]
# ## Gravity Lesson
#
# Gravity Lesson focuses on this skill: **See how gravity works in my platformer game**
#
# When you review your project, you should be able to point to **my platformer/gravity lesson** as evidence.

# %% [markdown]
# ## Why Gravity Lesson matters
#
# - This helps show that you can see how gravity works in my platformer game.
# - A reviewer can verify it by checking my platformer/gravity lesson.
# - The example below gives you a small starting point before you connect the idea to your own game.

# %%
# %%js
#
# // CODE_RUNNER: Gravity Lesson - practice the idea below.
#
# // Goal: See how gravity works in my platformer game
# // Look for: my platformer/gravity lesson
#
# const lesson = {
#   topic: "Gravity",
#   evidence: "my platformer/gravity lesson",
#   complete: false
# };
#
# function explainLesson(item) {
#   console.log(item.topic + ": " + item.evidence);
# }
#
# explainLesson(lesson);

# %% [markdown]
# ## Homework

# %%
# %%js
#
# // CODE_RUNNER: Homework - make your own example for Gravity Lesson.
#
# // TODO: Write code that shows this skill:
# // See how gravity works in my platformer game
#
# console.log("Add your own example here.");
