# %% [raw]
# ---
# layout: post
# categories: [CSSE JavaScript]
# microblog: true
# codemirror: true
# title: Async Lesson
# description: Learn how to wait for API results correctly and identify async/await or .then().
# permalink: /college-ready/asynchronous-io
# ---

# %% [markdown]
# ## Async Lesson
#
# Async Lesson focuses on this skill: **Wait for API results correctly**
#
# When you review your project, you should be able to point to **async/await or .then()** as evidence.

# %% [markdown]
# ## Why Async Lesson matters
#
# - This helps show that you can wait for API results correctly.
# - A reviewer can verify it by checking async/await or .then().
# - The example below gives you a small starting point before you connect the idea to your own game.

# %%
# %%js
#
# // CODE_RUNNER: Async Lesson - practice the idea below.
#
# // Goal: Wait for API results correctly
# // Look for: async/await or .then()
#
# const lesson = {
#   topic: "Async",
#   evidence: "async/await or .then()",
#   complete: false
# };
#
# function explainLesson(item) {
#   console.log(item.topic + ": " + item.evidence);
# }
#
# explainLesson(lesson);

# %% [markdown]
# ## Homework

# %%
# %%js
#
# // CODE_RUNNER: Homework - make your own example for Async Lesson.
#
# // TODO: Write code that shows this skill:
# // Wait for API results correctly
#
# console.log("Add your own example here.");
