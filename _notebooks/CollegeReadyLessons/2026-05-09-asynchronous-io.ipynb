# %% [markdown]
# <details class="college-ready-dropdown">
# <summary>APIs and Data Loading</summary>
#
# <details class="college-ready-subdropdown">
# <summary>Asynchronous I/O</summary>
#
# Asynchronous I/O lets JavaScript begin a task that may finish later. This keeps pages responsive while data loads.
#
# <pre><code class="language-javascript">Promise.resolve("Ava").then(name =&gt; console.log(name));</code></pre>
#
# </details>
# </details>
