# %% [raw]
# ---
# layout: post
# categories: [CSSE JavaScript]
# microblog: true
# codemirror: true
# title: Async Lesson
# description: Learn what Asynchronous I/O means, how it works in the Astro Platformer game, and how to practice it with a small homework task.
# permalink: /college-ready/asynchronous-io
# ---

# %% [markdown]
# ## Async Lesson
#
# ### What it is
#
# Asynchronous I/O means code can start a slow task, like loading data from an API, and continue without freezing the whole page.
#
# ### How it connects to our Astro Platformer
#
# Astro Platformer may need asynchronous code for loading assets, saving scores, or waiting for leaderboard/API results.
#
# Evidence to check: `_projects/games/astronaut-platformer-game/levels/astroplatformer.js`, the playable page `/astro-platgame/`, and the gravity write-up `/gravity_blog`.

# %% [markdown]
# ## Why this matters in Astro Platformer
#
# - A fetch request for leaderboard data should wait for the server response before using the data.
# - This lesson is not separate from the project; it is a way to explain one part of our Astro Platformer game.
# - A reviewer should be able to connect this topic back to the actual game code, gameplay, or documentation.

# %%
# %%js
#
# // CODE_RUNNER: Async Lesson - Astro Platformer connection.
#
# const astroLesson = {
#   game: "Astro Platformer",
#   topic: "Asynchronous I/O",
#   codeEvidence: "_projects/games/astronaut-platformer-game/levels/astroplatformer.js",
#   playablePage: "/astro-platgame/",
#   connection: "Astro Platformer may need asynchronous code for loading assets, saving scores, or waiting for leaderboard/API results."
# };
#
# function explainAstroConnection(lesson) {
#   console.log(lesson.topic + " in " + lesson.game);
#   console.log("Evidence: " + lesson.codeEvidence);
#   console.log(lesson.connection);
# }
#
# explainAstroConnection(astroLesson);

# %% [markdown]
# ## Homework
#
# Describe one Astro Platformer action that should wait for a result, such as loading scores or saving coins.
#
# Keep it small: write 2-3 sentences or fill in the starter code below. Your answer should mention **Astro Platformer** and one specific file, feature, variable, or gameplay moment.

# %%
# %%js
#
# // CODE_RUNNER: Homework - connect Asynchronous I/O back to Astro Platformer.
#
# const homework = {
#   game: "Astro Platformer",
#   topic: "Asynchronous I/O",
#   fileToCheck: "_projects/games/astronaut-platformer-game/levels/astroplatformer.js",
#   task: "Describe one Astro Platformer action that should wait for a result, such as loading scores or saving coins.",
#   yourAnswer: "Fill in the async action and what should happen after it finishes."
# };
#
# console.log("Homework topic: " + homework.topic);
# console.log("Task: " + homework.task);
# console.log("My answer: " + homework.yourAnswer);
