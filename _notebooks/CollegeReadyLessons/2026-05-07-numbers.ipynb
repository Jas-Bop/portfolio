# %% [raw]
# ---
# layout: post
# categories: [CSSE JavaScript]
# microblog: true
# codemirror: true
# title: Numbers Lesson
# description: Learn how to use numbers for things like position, speed, or score and identify number values in code.
# permalink: /college-ready/numbers
# ---

# %% [markdown]
# ## Numbers Lesson
#
# Numbers Lesson focuses on this skill: **Use numbers for things like position, speed, or score**
#
# When you review your project, you should be able to point to **number values in code** as evidence.

# %% [markdown]
# ## Why Numbers Lesson matters
#
# - This helps show that you can use numbers for things like position, speed, or score.
# - A reviewer can verify it by checking number values in code.
# - The example below gives you a small starting point before you connect the idea to your own game.

# %%
# %%js
#
# // CODE_RUNNER: Numbers Lesson - practice the idea below.
#
# // Goal: Use numbers for things like position, speed, or score
# // Look for: number values in code
#
# const lesson = {
#   topic: "Numbers",
#   evidence: "number values in code",
#   complete: false
# };
#
# function explainLesson(item) {
#   console.log(item.topic + ": " + item.evidence);
# }
#
# explainLesson(lesson);

# %% [markdown]
# ## Homework

# %%
# %%js
#
# // CODE_RUNNER: Homework - make your own example for Numbers Lesson.
#
# // TODO: Write code that shows this skill:
# // Use numbers for things like position, speed, or score
#
# console.log("Add your own example here.");
