# %% [markdown]
# <details class="college-ready-dropdown">
# <summary>Data Types</summary>
#
# <details class="college-ready-subdropdown">
# <summary>Numbers</summary>
#
# Numbers represent values that can be counted, measured, compared, or calculated. JavaScript uses numbers for scores, prices, positions, sizes, and percentages.
#
# <pre><code class="language-javascript">let price = 12;
# let quantity = 4;
# let total = price * quantity;</code></pre>
#
# </details>
# </details>
