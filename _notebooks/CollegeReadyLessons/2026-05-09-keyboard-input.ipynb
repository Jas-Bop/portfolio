# %% [markdown]
# <details class="college-ready-dropdown">
# <summary>Browser and Game Interaction</summary>
#
# <details class="college-ready-subdropdown">
# <summary>Keyboard Input</summary>
#
# Keyboard input maps key presses to program actions. It is commonly used for games, shortcuts, forms, and interactive controls.
#
# <pre><code class="language-javascript">let key = "ArrowLeft";
# if (key === "ArrowLeft") console.log("Move left");</code></pre>
#
# </details>
# </details>
