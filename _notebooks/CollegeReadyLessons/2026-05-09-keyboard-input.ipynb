# %% [raw]
# ---
# layout: post
# categories: [CSSE JavaScript]
# microblog: true
# codemirror: true
# title: Game Runner Lesson
# description: Learn how to let keys control the game and identify pressing the keys.
# permalink: /college-ready/keyboard-input
# ---

# %% [markdown]
# ## Game Runner Lesson
#
# Game Runner Lesson focuses on this skill: **Let keys control the game**
#
# When you review your project, you should be able to point to **pressing the keys** as evidence.

# %% [markdown]
# ## Why Game Runner Lesson matters
#
# - This helps show that you can let keys control the game.
# - A reviewer can verify it by checking pressing the keys.
# - The example below gives you a small starting point before you connect the idea to your own game.

# %%
# %%js
#
# // CODE_RUNNER: Game Runner Lesson - practice the idea below.
#
# // Goal: Let keys control the game
# // Look for: pressing the keys
#
# const lesson = {
#   topic: "Game Runner",
#   evidence: "pressing the keys",
#   complete: false
# };
#
# function explainLesson(item) {
#   console.log(item.topic + ": " + item.evidence);
# }
#
# explainLesson(lesson);

# %% [markdown]
# ## Homework

# %%
# %%js
#
# // CODE_RUNNER: Homework - make your own example for Game Runner Lesson.
#
# // TODO: Write code that shows this skill:
# // Let keys control the game
#
# console.log("Add your own example here.");
