# %% [raw]
# ---
# layout: post
# categories: [CSSE JavaScript]
# microblog: true
# codemirror: true
# title: Inheritance Lesson
# description: Learn how to use classes that build on other classes and identify the extends keyword.
# permalink: /college-ready/inheritance-basic
# ---

# %% [markdown]
# ## Inheritance Lesson
#
# Inheritance Lesson focuses on this skill: **Use classes that build on other classes**
#
# When you review your project, you should be able to point to **the extends keyword** as evidence.

# %% [markdown]
# ## Why Inheritance Lesson matters
#
# - This helps show that you can use classes that build on other classes.
# - A reviewer can verify it by checking the extends keyword.
# - The example below gives you a small starting point before you connect the idea to your own game.

# %%
# %%js
#
# // CODE_RUNNER: Inheritance Lesson - practice the idea below.
#
# // Goal: Use classes that build on other classes
# // Look for: the extends keyword
#
# const lesson = {
#   topic: "Inheritance",
#   evidence: "the extends keyword",
#   complete: false
# };
#
# function explainLesson(item) {
#   console.log(item.topic + ": " + item.evidence);
# }
#
# explainLesson(lesson);

# %% [markdown]
# ## Homework

# %%
# %%js
#
# // CODE_RUNNER: Homework - make your own example for Inheritance Lesson.
#
# // TODO: Write code that shows this skill:
# // Use classes that build on other classes
#
# console.log("Add your own example here.");
