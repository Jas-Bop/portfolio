# %% [raw]
# ---
# layout: post
# categories: [CSSE JavaScript]
# microblog: true
# codemirror: true
# title: Inheritance Lesson
# description: Learn what Inheritance means, how it works in the Astro Platformer game, and how to practice it with a small homework task.
# permalink: /college-ready/inheritance-basic
# ---

# %% [markdown]
# ## Inheritance Lesson
#
# ### What it is
#
# Inheritance lets one class reuse behavior from another class. The child class gets parent features and can add or change details.
#
# ### How it connects to our Astro Platformer
#
# Astro Platformer can reuse engine classes while customizing objects for this specific space platformer level.
#
# Evidence to check: `_projects/games/astronaut-platformer-game/levels/astroplatformer.js`, the playable page `/astro-platgame/`, and the gravity write-up `/gravity_blog`.

# %% [markdown]
# ## Why this matters in Astro Platformer
#
# - FixedPlatformerCoin inherits from Coin, then changes update and collect behavior for the level.
# - This lesson is not separate from the project; it is a way to explain one part of our Astro Platformer game.
# - A reviewer should be able to connect this topic back to the actual game code, gameplay, or documentation.

# %%
# %%js
#
# // CODE_RUNNER: Inheritance Lesson - Astro Platformer connection.
#
# const astroLesson = {
#   game: "Astro Platformer",
#   topic: "Inheritance",
#   codeEvidence: "_projects/games/astronaut-platformer-game/levels/astroplatformer.js",
#   playablePage: "/astro-platgame/",
#   connection: "Astro Platformer can reuse engine classes while customizing objects for this specific space platformer level."
# };
#
# function explainAstroConnection(lesson) {
#   console.log(lesson.topic + " in " + lesson.game);
#   console.log("Evidence: " + lesson.codeEvidence);
#   console.log(lesson.connection);
# }
#
# explainAstroConnection(astroLesson);

# %% [markdown]
# ## Homework
#
# Identify one parent/child relationship or reusable class idea in Astro Platformer.
#
# Keep it small: write 2-3 sentences or fill in the starter code below. Your answer should mention **Astro Platformer** and one specific file, feature, variable, or gameplay moment.

# %%
# %%js
#
# // CODE_RUNNER: Homework - connect Inheritance back to Astro Platformer.
#
# const homework = {
#   game: "Astro Platformer",
#   topic: "Inheritance",
#   fileToCheck: "_projects/games/astronaut-platformer-game/levels/astroplatformer.js",
#   task: "Identify one parent/child relationship or reusable class idea in Astro Platformer.",
#   yourAnswer: "Fill in parent class, child class, and what the child changes."
# };
#
# console.log("Homework topic: " + homework.topic);
# console.log("Task: " + homework.task);
# console.log("My answer: " + homework.yourAnswer);
