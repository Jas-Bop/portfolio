# %% [markdown]
# <details class="college-ready-dropdown">
# <summary>APIs and Data Loading</summary>
#
# <details class="college-ready-subdropdown">
# <summary>JSON Parsing</summary>
#
# JSON parsing converts JSON text into JavaScript data. This is common when data comes from APIs, files, or browser storage.
#
# <pre><code class="language-javascript">const jsonText = '{"name":"Ava"}';
# const data = JSON.parse(jsonText);</code></pre>
#
# </details>
# </details>
