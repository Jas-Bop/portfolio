# %% [raw]
# ---
# layout: post
# categories: [CSSE JavaScript]
# microblog: true
# codemirror: true
# title: JSON Parsing Lesson
# description: Learn how to read JSON data from an API and identify JSON.parse() or response data.
# permalink: /college-ready/json-parsing
# ---

# %% [markdown]
# ## JSON Parsing Lesson
#
# JSON Parsing Lesson focuses on this skill: **Read JSON data from an API**
#
# When you review your project, you should be able to point to **JSON.parse() or response data** as evidence.

# %% [markdown]
# ## Why JSON Parsing Lesson matters
#
# - This helps show that you can read JSON data from an API.
# - A reviewer can verify it by checking JSON.parse() or response data.
# - The example below gives you a small starting point before you connect the idea to your own game.

# %%
# %%js
#
# // CODE_RUNNER: JSON Parsing Lesson - practice the idea below.
#
# // Goal: Read JSON data from an API
# // Look for: JSON.parse() or response data
#
# const lesson = {
#   topic: "JSON Parsing",
#   evidence: "JSON.parse() or response data",
#   complete: false
# };
#
# function explainLesson(item) {
#   console.log(item.topic + ": " + item.evidence);
# }
#
# explainLesson(lesson);

# %% [markdown]
# ## Homework

# %%
# %%js
#
# // CODE_RUNNER: Homework - make your own example for JSON Parsing Lesson.
#
# // TODO: Write code that shows this skill:
# // Read JSON data from an API
#
# console.log("Add your own example here.");
