# %% [raw]
# ---
# layout: post
# categories: [CSSE JavaScript]
# microblog: true
# codemirror: true
# title: Mini-Lesson Documentation
# description: Learn how to make a visual lesson post with a playable demo and identify your portfolio lesson page.
# permalink: /college-ready/mini-lesson-documentation
# ---

# %% [markdown]
# ## Mini-Lesson Documentation
#
# Mini-Lesson Documentation focuses on this skill: **Make a visual lesson post with a playable demo**
#
# When you review your project, you should be able to point to **your portfolio lesson page** as evidence.

# %% [markdown]
# ## Why Mini-Lesson Documentation matters
#
# - This helps show that you can make a visual lesson post with a playable demo.
# - A reviewer can verify it by checking your portfolio lesson page.
# - The example below gives you a small starting point before you connect the idea to your own game.

# %%
# %%js
#
# // CODE_RUNNER: Mini-Lesson Page - practice the idea below.
#
# // Goal: Make a visual lesson post with a playable demo
# // Look for: your portfolio lesson page
#
# const lesson = {
#   topic: "Mini-Lesson Page",
#   evidence: "your portfolio lesson page",
#   complete: false
# };
#
# function explainLesson(item) {
#   console.log(item.topic + ": " + item.evidence);
# }
#
# explainLesson(lesson);

# %% [markdown]
# ## Homework

# %%
# %%js
#
# // CODE_RUNNER: Homework - make your own example for Mini-Lesson Page.
#
# // TODO: Write code that shows this skill:
# // Make a visual lesson post with a playable demo
#
# console.log("Add your own example here.");
