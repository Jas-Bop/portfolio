# %% [markdown]
# <details class="college-ready-dropdown">
# <summary>Documentation</summary>
#
# <details class="college-ready-subdropdown">
# <summary>Mini-Lesson Documentation</summary>
#
# Mini-lesson documentation explains one focused concept in a way that another person can understand and use.
#
# <pre><code class="language-javascript">const miniLesson = { topic: "Arrays", definition: "An ordered list" };</code></pre>
#
# </details>
# </details>
