# %% [raw]
# ---
# layout: post
# categories: [CSSE JavaScript]
# microblog: true
# codemirror: true
# title: Mini-Lesson Documentation
# description: Learn what Mini-lesson documentation means, how it works in the Astro Platformer game.
# permalink: /college-ready/mini-lesson-documentation
# ---

# %% [markdown]
# ## Mini-Lesson Documentation
#
# ### What it is
#
# Mini-lesson documentation is a short teaching page that explains one topic, shows where it appears in a project, and gives classmates a small practice task.
#
# ### How it connects to our Astro Platformer
#
# This mini-lesson page should point back to the Astro Platformer gravity lesson, the playable Astro game, and the astroplatformer.js code evidence.
#
# Evidence to check: `_projects/games/astronaut-platformer-game/levels/astroplatformer.js`, the playable page `/astro-platgame/`, and the gravity write-up `/gravity_blog`.

# %% [markdown]
# ## Why this matters in Astro Platformer
#
# - The gravity lesson explains how the astronaut falls, jumps, lands on platforms, and reaches the flag.
# - This lesson is not separate from the project; it is a way to explain one part of our Astro Platformer game.
# - A reviewer should be able to connect this topic back to the actual game code, gameplay, or documentation.

# %%
# %%js
#
# // CODE_RUNNER: Mini-Lesson Documentation - Astro Platformer connection.
#
# const astroLesson = {
#   game: "Astro Platformer",
#   topic: "Mini-lesson documentation",
#   codeEvidence: "_projects/games/astronaut-platformer-game/levels/astroplatformer.js",
#   playablePage: "/astro-platgame/",
#   connection: "This mini-lesson page should point back to the Astro Platformer gravity lesson, the playable Astro game, and the astroplatformer.js code evidence."
# };
#
# function explainAstroConnection(lesson) {
#   console.log(lesson.topic + " in " + lesson.game);
#   console.log("Evidence: " + lesson.codeEvidence);
#   console.log(lesson.connection);
# }
#
# explainAstroConnection(astroLesson);
