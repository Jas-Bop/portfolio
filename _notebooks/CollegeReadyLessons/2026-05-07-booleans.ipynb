# %% [markdown]
# <details class="college-ready-dropdown">
# <summary>Programming Fundamentals</summary>
#
# <details class="college-ready-subdropdown">
# <summary>Booleans</summary>
#
# Booleans store true or false values. They are used to track state and control program decisions, such as whether a user is logged in or whether a form is complete.
#
# <pre><code class="language-javascript">let isLoggedIn = true;
# let hasProfile = false;
#
# if (isLoggedIn &amp;&amp; hasProfile) {
#   console.log("Open dashboard");
# }</code></pre>
#
# </details>
# </details>
