# %% [raw]
# ---
# layout: post
# categories: [CSSE JavaScript]
# microblog: true
# codemirror: true
# title: Booleans Lesson
# description: Learn how to use true/false values for game states and identify boolean values and checks.
# permalink: /college-ready/booleans
# ---

# %% [markdown]
# ## Booleans Lesson
#
# Booleans Lesson focuses on this skill: **Use true/false values for game states**
#
# When you review your project, you should be able to point to **boolean values and checks** as evidence.

# %% [markdown]
# ## Why Booleans Lesson matters
#
# - This helps show that you can use true/false values for game states.
# - A reviewer can verify it by checking boolean values and checks.
# - The example below gives you a small starting point before you connect the idea to your own game.

# %%
# %%js
#
# // CODE_RUNNER: Booleans Lesson - practice the idea below.
#
# // Goal: Use true/false values for game states
# // Look for: boolean values and checks
#
# const lesson = {
#   topic: "Booleans",
#   evidence: "boolean values and checks",
#   complete: false
# };
#
# function explainLesson(item) {
#   console.log(item.topic + ": " + item.evidence);
# }
#
# explainLesson(lesson);

# %% [markdown]
# ## Homework

# %%
# %%js
#
# // CODE_RUNNER: Homework - make your own example for Booleans Lesson.
#
# // TODO: Write code that shows this skill:
# // Use true/false values for game states
#
# console.log("Add your own example here.");
