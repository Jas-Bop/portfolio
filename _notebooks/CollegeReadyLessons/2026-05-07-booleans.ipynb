# %% [raw]
# ---
# layout: post
# categories: [CSSE JavaScript]
# microblog: true
# codemirror: true
# title: Booleans Lesson
# description: Learn what Booleans means, how it works in the Astro Platformer game, and how to practice it with a small homework task.
# permalink: /college-ready/booleans
# ---

# %% [markdown]
# ## Booleans Lesson
#
# ### What it is
#
# A boolean is a value that can only be true or false. In code, booleans answer yes/no questions like "is the player alive?" or "has the coin been collected?"
#
# ### How it connects to our Astro Platformer
#
# Astro Platformer uses boolean state for things like whether the astronaut is on the ground, whether the player has won, whether the player is dead, and whether a coin has already been collected.
#
# Evidence to check: `_projects/games/astronaut-platformer-game/levels/astroplatformer.js`, the playable page `/astro-platgame/`, and the gravity write-up `/gravity_blog`.

# %% [markdown]
# ## Why this matters in Astro Platformer
#
# - Use true/false flags such as _onGround, _won, _isDead, and collected to control what happens next.
# - This lesson is not separate from the project; it is a way to explain one part of our Astro Platformer game.
# - A reviewer should be able to connect this topic back to the actual game code, gameplay, or documentation.

# %%
# %%js
#
# // CODE_RUNNER: Booleans Lesson - Astro Platformer connection.
#
# const astroLesson = {
#   game: "Astro Platformer",
#   topic: "Booleans",
#   codeEvidence: "_projects/games/astronaut-platformer-game/levels/astroplatformer.js",
#   playablePage: "/astro-platgame/",
#   connection: "Astro Platformer uses boolean state for things like whether the astronaut is on the ground, whether the player has won, whether the player is dead, and whether a coin has already been collected."
# };
#
# function explainAstroConnection(lesson) {
#   console.log(lesson.topic + " in " + lesson.game);
#   console.log("Evidence: " + lesson.codeEvidence);
#   console.log(lesson.connection);
# }
#
# explainAstroConnection(astroLesson);

# %% [markdown]
# ## Homework
#
# Find one true/false flag in the Astro Platformer code and explain what changes when it switches value.
#
# Keep it small: write 2-3 sentences or fill in the starter code below. Your answer should mention **Astro Platformer** and one specific file, feature, variable, or gameplay moment.

# %%
# %%js
#
# // CODE_RUNNER: Homework - connect Booleans back to Astro Platformer.
#
# const homework = {
#   game: "Astro Platformer",
#   topic: "Booleans",
#   fileToCheck: "_projects/games/astronaut-platformer-game/levels/astroplatformer.js",
#   task: "Find one true/false flag in the Astro Platformer code and explain what changes when it switches value.",
#   yourAnswer: "Change flagName to a real boolean variable you found, then set whatTrueMeans and whatFalseMeans."
# };
#
# console.log("Homework topic: " + homework.topic);
# console.log("Task: " + homework.task);
# console.log("My answer: " + homework.yourAnswer);
