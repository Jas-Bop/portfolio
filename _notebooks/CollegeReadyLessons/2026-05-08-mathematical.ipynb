# %% [raw]
# ---
# layout: post
# categories: [CSSE JavaScript]
# microblog: true
# codemirror: true
# title: Math Lesson
# description: Learn how to use math in the game and identify +, -, *, or /.
# permalink: /college-ready/mathematical
# ---

# %% [markdown]
# ## Math Lesson
#
# Math Lesson focuses on this skill: **Use math in the game**
#
# When you review your project, you should be able to point to **+, -, *, or /** as evidence.

# %% [markdown]
# ## Why Math Lesson matters
#
# - This helps show that you can use math in the game.
# - A reviewer can verify it by checking +, -, *, or /.
# - The example below gives you a small starting point before you connect the idea to your own game.

# %%
# %%js
#
# // CODE_RUNNER: Math Lesson - practice the idea below.
#
# // Goal: Use math in the game
# // Look for: +, -, *, or /
#
# const lesson = {
#   topic: "Math",
#   evidence: "+, -, *, or /",
#   complete: false
# };
#
# function explainLesson(item) {
#   console.log(item.topic + ": " + item.evidence);
# }
#
# explainLesson(lesson);

# %% [markdown]
# ## Homework

# %%
# %%js
#
# // CODE_RUNNER: Homework - make your own example for Math Lesson.
#
# // TODO: Write code that shows this skill:
# // Use math in the game
#
# console.log("Add your own example here.");
