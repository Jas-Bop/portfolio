# %% [markdown]
# <details class="college-ready-dropdown">
# <summary>Expressions and Operations</summary>
#
# <details class="college-ready-subdropdown">
# <summary>Math in Code</summary>
#
# Math expressions calculate new values from existing values. Programs use math for totals, averages, movement, size, scoring, and percentages.
#
# <pre><code class="language-javascript">let earned = 18;
# let possible = 20;
# let percent = (earned / possible) * 100;</code></pre>
#
# </details>
# </details>
