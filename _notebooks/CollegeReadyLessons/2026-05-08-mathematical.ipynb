# %% [raw]
# ---
# layout: post
# categories: [CSSE JavaScript]
# microblog: true
# codemirror: true
# title: Math Lesson
# description: Learn what Math in code means, how it works in the Astro Platformer game, and how to practice it with a small homework task.
# permalink: /college-ready/mathematical
# ---

# %% [markdown]
# ## Math Lesson
#
# ### What it is
#
# Math in code uses operations like addition, subtraction, multiplication, and division to calculate new values.
#
# ### How it connects to our Astro Platformer
#
# Astro Platformer uses math to move the astronaut, apply gravity, scale the level to the screen, count coins, and detect collisions.
#
# Evidence to check: `_projects/games/astronaut-platformer-game/levels/astroplatformer.js`, the playable page `/astro-platgame/`, and the gravity write-up `/gravity_blog`.

# %% [markdown]
# ## Why this matters in Astro Platformer
#
# - Adding gravity to vertical velocity each frame makes the astronaut fall faster until max fall speed stops it.
# - This lesson is not separate from the project; it is a way to explain one part of our Astro Platformer game.
# - A reviewer should be able to connect this topic back to the actual game code, gameplay, or documentation.

# %%
# %%js
#
# // CODE_RUNNER: Math Lesson - Astro Platformer connection.
#
# const astroLesson = {
#   game: "Astro Platformer",
#   topic: "Math in code",
#   codeEvidence: "_projects/games/astronaut-platformer-game/levels/astroplatformer.js",
#   playablePage: "/astro-platgame/",
#   connection: "Astro Platformer uses math to move the astronaut, apply gravity, scale the level to the screen, count coins, and detect collisions."
# };
#
# function explainAstroConnection(lesson) {
#   console.log(lesson.topic + " in " + lesson.game);
#   console.log("Evidence: " + lesson.codeEvidence);
#   console.log(lesson.connection);
# }
#
# explainAstroConnection(astroLesson);

# %% [markdown]
# ## Homework
#
# Write one Astro Platformer formula in words, such as y position plus vertical speed equals the next y position.
#
# Keep it small: write 2-3 sentences or fill in the starter code below. Your answer should mention **Astro Platformer** and one specific file, feature, variable, or gameplay moment.

# %%
# %%js
#
# // CODE_RUNNER: Homework - connect Math in code back to Astro Platformer.
#
# const homework = {
#   game: "Astro Platformer",
#   topic: "Math in code",
#   fileToCheck: "_projects/games/astronaut-platformer-game/levels/astroplatformer.js",
#   task: "Write one Astro Platformer formula in words, such as y position plus vertical speed equals the next y position.",
#   yourAnswer: "Fill in the formula parts for one movement, gravity, score, or scale calculation."
# };
#
# console.log("Homework topic: " + homework.topic);
# console.log("Task: " + homework.task);
# console.log("My answer: " + homework.yourAnswer);
