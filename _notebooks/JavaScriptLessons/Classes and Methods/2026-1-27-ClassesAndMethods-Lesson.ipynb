# %% [markdown]
# ---
# title: Classes hw
# comments: true
# codemirror: true
# microblog: true
# layout: post
# permalink: /js/classes
# description: classes hw
# author: Me
# ---

# %% [markdown]
# ## Homework

# %%
# %%js
#
# class Dog {
#     bark() {
#         console.log("Woof!");
#     }
#
#     eat() {
#         console.log("Dog is eating.");
#     }
# }
#
# let myDog = new Dog();
#
# myDog.bark();
# myDog.eat();
