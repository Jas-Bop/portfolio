# %% [markdown]
# ---
# layout: post
# title: Classes Homework
# description: Complete the Classes homework assignment for CSSE JavaScript Fundamentals.
# author: Me
# permalink: /js/classes
# ---

# %% [markdown]
# ## Homework

# %%
class Dog {
    bark() {
        console.log("Woof!");
    }

    eat() {
        console.log("Dog is eating.");
    }
}

let myDog = new Dog();

myDog.bark();
myDog.eat();
