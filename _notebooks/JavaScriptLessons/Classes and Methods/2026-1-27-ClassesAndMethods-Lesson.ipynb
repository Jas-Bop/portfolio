# %% [markdown]
# ## Homework

# %% [markdown]
# class Dog {
#     bark() {
#         console.log("Woof!");
#     }
#
#     eat() {
#         console.log("Dog is eating.");
#     }
# }
#
# let myDog = new Dog();
#
# myDog.bark();
# myDog.eat();
