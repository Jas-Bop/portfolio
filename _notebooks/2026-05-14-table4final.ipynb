# %% [markdown]
# ---
# layout: post
# title: Final Project Evidence Table
# description: Learning objectives, project evidence, and assessment methods for the final game project.
# permalink: /table4final
# ---

# %% [markdown]
# <style>
# .final-table-wrap { max-width: 980px; margin: 18px auto; }
# .final-table-title { margin: 0 0 6px; font-size: 2rem; line-height: 1.15; }
# .final-table-note { margin: 0 0 18px; color: #667085; font-size: 1rem; }
# .final-table { width: 100%; border-collapse: separate; border-spacing: 0; overflow: hidden; border: 1px solid #d9e2ec; border-radius: 10px; background: #fff; box-shadow: 0 10px 28px rgba(15, 23, 42, 0.08); }
# .final-table th { background: #132238; color: #fff; text-align: left; padding: 12px 14px; font-size: 0.95rem; }
# .final-table td { padding: 12px 14px; border-top: 1px solid #e8eef5; vertical-align: top; }
# .final-table tr:nth-child(even) td { background: #f8fafc; }
# .final-table .group td { background: #e6f4f1; color: #0f766e; font-weight: 800; text-transform: uppercase; letter-spacing: 0.04em; font-size: 0.82rem; }
# .pill { display: inline-block; padding: 5px 10px; border-radius: 999px; background: #eef2ff; color: #3730a3; font-weight: 700; font-size: 0.82rem; text-decoration: none; border: 1px solid #c7d2fe; transition: transform 0.15s, box-shadow 0.15s; }
# .pill:hover { transform: translateY(-1px); box-shadow: 0 5px 14px rgba(55, 48, 163, 0.18); text-decoration: none; }
# @media (max-width: 720px) { .final-table th, .final-table td { padding: 10px; font-size: 0.9rem; } .final-table-title { font-size: 1.55rem; } }
# </style>
#
# <div class="final-table-wrap">
#   <h1 class="final-table-title">Final Project Evidence</h1>
#   <p class="final-table-note">A simple checklist for what my game project needs to prove.</p>
#   <table class="final-table">
#     <thead>
#       <tr><th>Topic</th><th>Evidence</th><th>How It Is Checked</th></tr>
#     </thead>
#     <tbody>
#       <tr class="group"><td colspan="3">Object-Oriented Programming</td></tr>
#       <tr><td><a class="pill" href="{{site.baseurl}}/js/classes">Classes</a></td><td>2+ custom character classes</td><td>Review class files and <code>extends</code></td></tr>
#       <tr><td><a class="pill" href="{{site.baseurl}}/js/classes">Methods</a></td><td>Methods with parameters and overrides</td><td>Review method signatures</td></tr>
#       <tr><td><a class="pill" href="{{site.baseurl}}/js/classes">Objects</a></td><td>Game objects created in level setup</td><td>Review GameLevel configuration</td></tr>
#       <tr class="group"><td colspan="3">Game Logic</td></tr>
#       <tr><td><a class="pill" href="{{site.baseurl}}/js/iterations">Loops</a></td><td>Animation, objects, and level updates</td><td>Look for <code>for</code>, <code>forEach</code>, update loops</td></tr>
#       <tr><td><a class="pill" href="{{site.baseurl}}/js/nested-conditionals">Conditions</a></td><td>Collision, state, and direction checks</td><td>Review <code>if</code>, <code>else</code>, nested logic</td></tr>
#       <tr><td><a class="pill" href="{{site.baseurl}}/js/json">Data</a></td><td>Numbers, strings, booleans, arrays, objects</td><td>Review config and game state</td></tr>
#       <tr class="group"><td colspan="3">Input, Output, and APIs</td></tr>
#       <tr><td><a class="pill" href="{{site.baseurl}}/gamerunner">Controls</a></td><td>Keyboard input for movement/actions</td><td>Play test key response</td></tr>
#       <tr><td><a class="pill" href="{{site.baseurl}}/code/ui">Canvas</a></td><td>Sprites, backgrounds, and platforms render</td><td>Review and test draw methods</td></tr>
#       <tr><td><a class="pill" href="{{site.baseurl}}/network/stack">API</a></td><td>Leaderboard or score fetch calls</td><td>Check async code and errors</td></tr>
#       <tr class="group"><td colspan="3">Documentation and Testing</td></tr>
#       <tr><td><a class="pill" href="{{site.baseurl}}/astro-platgame-lesson/">Lesson</a></td><td>Visual post with game demo and code highlights</td><td>Portfolio review</td></tr>
#       <tr><td><a class="pill" href="{{site.baseurl}}/gravity_blog">Debugging</a></td><td>Console, hit boxes, DevTools, Network tab</td><td>Live demo/debug walkthrough</td></tr>
#       <tr><td><a class="pill" href="{{site.baseurl}}/astro-platgame/">Testing</a></td><td>Gameplay, integration, and API error handling</td><td>Play through without major bugs</td></tr>
#     </tbody>
#   </table>
# </div>
